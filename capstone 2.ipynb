# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log
import pandas as pd
import numpy as np
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/suneherahasib/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import re
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import string
from nltk.corpus import stopwords
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from collections import Counter
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import gensim
from sklearn.model_selection import train_test_split
import spacy
from sklearn.decomposition import NMF, LatentDirichletAllocation
import pyLDAvis
import pyLDAvis.sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from pprint import pprint
from time import time
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from sklearn.metrics import precision_score, recall_score, accuracy_score,roc_auc_score
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import keras
print('Done')
# Out:
# 2023-04-16 21:16:55.120616: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Done

# %%
data = pd.read_csv('tweets4f.csv', usecols=['text'])

# %%
data
# Out:
#                                                    text
# 0     Maybe the disasters won't end. But you CAN get...
# 1     i wish i didn’t have social anxiety bc the thi...
# 2     𝐼 𝓇𝑒𝒶𝓁𝒾𝓏𝑒 𝓉𝒽𝒶𝓉 #happiness \nhas been 𝐢𝐧𝐬𝐢𝐝𝐞 𝐨𝐟...
# 3       We understand this feeling! #CFS #Fibromyalg...
# 4     i am so grateful because things are always wor...
# ...                                                 ...
# 7622  Thank You, Jesus, for dying for me. #HolyWeek ...
# 7623   #Depression 😭😭😭 .how do you feel when you los...
# 7624  I  have no reason to live. I'm going to hurt s...
# 7625  True happiness comes from within - it's not ab...
# 7626  I am at that phase of life when i listen to mu...
#
# [7627 rows x 1 columns]

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

for i in range(len(data)):
  data.at[i,'text'] = remove_urls(data.iloc[i]['text'])
data.tail()
# Out:
#                                                    text
# 7622  Thank You, Jesus, for dying for me. #HolyWeek ...
# 7623   #Depression 😭😭😭 .how do you feel when you los...
# 7624  I  have no reason to live. I'm going to hurt s...
# 7625  True happiness comes from within - it's not ab...
# 7626  I am at that phase of life when i listen to mu...

# %%
from sklearn.decomposition import TruncatedSVD

# %%
text_data =  data['text'].values.tolist()

# Remove Emails
text_data = [re.sub('\S*@\S*\s?', '', sent) for sent in text_data ]

# Remove new line characters
text_data= [re.sub('\s+', ' ', sent) for sent in text_data]

# Remove distracting single quotes
text_data = [re.sub("\'", "", sent) for sent in text_data]

text_data = [re.sub(r'[^\w\s]+', '', sent) for sent in text_data]


text_data = [[word for word in doc.lower().split()] for doc in data['text']]


print(text_data[:1])
# Out:
# [['maybe', 'the', 'disasters', "won't", 'end.', 'but', 'you', 'can', 'get', 'through', 'them', 'for', 'that', 'little', 'light', 'of', 'hope', "that's", 'still', 'there', 'in', 'you.', 'i', 'know', 'it', 'is.', 'i', 'promise', 'it', 'is.', 'it', 'might', 'be', 'small.', 'maybe', 'even', 'hidden.', 'but', 'i', 'promise', 'you,', "it's", 'there.', '#depression', '#anxiety', '#mentalillness', '#mentalhealthawareness']]

# %%
text_data
# Out:
# [['maybe',
#   'the',
#   'disasters',
#   "won't",
#   'end.',
#   'but',
#   'you',
#   'can',
#   'get',
#   'through',
#   'them',
#   'for',
#   'that',
#   'little',
#   'light',
#   'of',
#   'hope',
#   "that's",
#   'still',
#   'there',
#   'in',
#   'you.',
#   'i',
#   'know',
#   'it',
#   'is.',
#   'i',
#   'promise',
#   'it',
#   'is.',
#   'it',
#   'might',
#   'be',
#   'small.',
#   'maybe',
#   'even',
#   'hidden.',
#   'but',
#   'i',
#   'promise',
#   'you,',
#   "it's",
#   'there.',
#   '#depression',
#   '#anxiety',
#   '#mentalillness',
#   '#mentalhealthawareness'],
#  ['i',
#   'wish',
#   'i',
#   'didn’t',
#   'have',
#   'social',
#   'anxiety',
#   'bc',
#   'the',
#   'things',
#   'i',
#   'would',
#   'do',
#   'to',
#   'become',
#   'an',
#   'actor'],
#  ['𝐼',
#   '𝓇𝑒𝒶𝓁𝒾𝓏𝑒',
#   '𝓉𝒽𝒶𝓉',
#   '#happiness',
#   'has',
#   'been',
#   '𝐢𝐧𝐬𝐢𝐝𝐞',
#   '𝐨𝐟',
#   '𝐦𝐞',
#   'all',
#   'this',
#   'time,',
#   'i',
#   'just',
#   '𝐡𝐚𝐝',
#   '𝐭𝐨',
#   '𝐜𝐡𝐚𝐧𝐠𝐞',
#   'the',
#   'way',
#   'i',
#   'think.',
#   '#mindsetmatters'],
#  ['we',
#   'understand',
#   'this',
#   'feeling!',
#   '#cfs',
#   '#fibromyalgia',
#   '#anxiety',
#   '#depression'],
#  ['i',
#   'am',
#   'so',
#   'grateful',
#   'because',
#   'things',
#   'are',
#   'always',
#   'working',
#   'out',
#   'for',
#   'me',
#   '😁🙌🏾✨'],
#  ['i',
#   'like',
#   'having',
#   'an',
#   'empty',
#   'mind',
#   'no',
#   '#anxiety',
#   '#stress',
#   'or',
#   '#depression.',
#   'i',
#   'like',
#   '#peace',
#   'and',
#   '#abundance'],
#  ['god',
#   'is',
#   'good!',
#   'thank',
#   'you',
#   'to',
#   'everyone',
#   'who',
#   'said',
#   'prayers',
#   'for',
#   'naiyah',
#   'her',
#   'bone',
#   'density',
#   'scans',
#   'came',
#   'back',
#   'normal',
#   'this',
#   'morning.',
#   'still',
#   'have',
#   'to',
#   'do',
#   'genetic',
#   'testing',
#   'but',
#   'it’s',
#   'a',
#   'step',
#   'in',
#   'a',
#   'better',
#   'direction',
#   'and',
#   'makes',
#   'us',
#   'hopeful!',
#   'one',
#   'test',
#   'down',
#   'and',
#   'one',
#   'to',
#   'go!',
#   '#thankful'],
#  ['#anxiety',
#   'hunger',
#   'is',
#   'like',
#   'being',
#   'hungry',
#   'in',
#   'the',
#   'least',
#   'hungry',
#   'way',
#   'possible.',
#   'you',
#   'know,',
#   'wanting',
#   'food',
#   'without',
#   'having',
#   'to',
#   'eat',
#   'it?',
#   'does',
#   'that',
#   'make',
#   'sense?',
#   'anyways',
#   'my',
#   'cat',
#   'is',
#   'extremely',
#   'sick',
#   'right',
#   'now',
#   'so',
#   'if',
#   "i'm",
#   'not',
#   'avoiding',
#   'twitter',
#   "i'm",
#   'crying,',
#   'see',
#   'you',
#   'soon',
#   'with',
#   'an',
#   'unwanted',
#   'update',
#   '✌️'],
#  ['gratitude',
#   'can',
#   'transform',
#   'your',
#   'entire',
#   'perspective',
#   'on',
#   'life.',
#   'start',
#   'each',
#   'day',
#   'with',
#   'a',
#   'grateful',
#   'heart.',
#   '#gratitude',
#   '#thankful',
#   '#mindset'],
#  ['for',
#   'real',
#   'though',
#   'if',
#   'someone',
#   'got',
#   'me',
#   'this',
#   'either',
#   'soon',
#   'or',
#   'on',
#   'my',
#   'birthday',
#   '(may',
#   '6)',
#   'i',
#   'would',
#   'be',
#   'forever',
#   'grateful',
#   '❤️❤️'],
#  ['“i',
#   'believe',
#   'in',
#   'god,',
#   'only',
#   'i',
#   'spell',
#   'it',
#   'nature.”',
#   '~frank',
#   'lloyd',
#   'wright',
#   '#creativity',
#   '#gratitude',
#   '#motivation',
#   '#confidence',
#   '#affirmations',
#   '#quotes',
#   '#qotd',
#   '#inspirationalquotes',
#   '#imagination',
#   '#happiness',
#   '#positive',
#   '#success',
#   '#nature'],
#  ['dear',
#   'brothers',
#   ',',
#   '#depression',
#   'is',
#   'real,',
#   'but',
#   'together',
#   'we',
#   'can',
#   'prevent',
#   'it',
#   'with',
#   '#engageaman',
#   '#rwot',
#   '#mensmentalhealth',
#   '#mentalhealthmatters'],
#  ['back', 'in', 'america', '#depression'],
#  ['lol',
#   'this',
#   'happened',
#   'like',
#   'a',
#   'year',
#   'ago',
#   'i',
#   'think',
#   '!',
#   'it',
#   'was',
#   'so',
#   'random',
#   'but',
#   'i',
#   'am',
#   'very',
#   'grateful',
#   '\U0001fae1'],
#  ['both',
#   'vague',
#   'and',
#   'anxiety',
#   'inducing.',
#   ':-).',
#   'that',
#   'said,',
#   'thank',
#   'you',
#   'for',
#   'sharing',
#   'what',
#   'you',
#   'can.'],
#  ['fankoo',
#   'for',
#   'sharing',
#   'this',
#   'today.',
#   'i',
#   'feel',
#   'utterly',
#   'alone',
#   'often',
#   '&amp;',
#   'this',
#   'reminded',
#   'me',
#   'i’m',
#   'not',
#   '#depression',
#   '#anxiety',
#   '#mentalhealthmatters'],
#  ['have',
#   'you',
#   'thought',
#   'about',
#   'getting',
#   'help?',
#   '#mentalhealth',
#   '#depression'],
#  ['i',
#   'want',
#   'to',
#   'die.',
#   "i'm",
#   'going',
#   'to',
#   'hurt',
#   'someone',
#   '.',
#   '#anxiety'],
#  ['mama', 'is', 'triggering', 'my', 'anxiety', '😍😍'],
#  ['#stress',
#   'is',
#   'something',
#   'that',
#   'is',
#   'an',
#   'outside',
#   'thing.',
#   'stress',
#   'is',
#   'an',
#   '#anxiety.'],
#  ['people',
#   'who',
#   'used',
#   'to',
#   'participate',
#   'in',
#   'every',
#   'competition',
#   'and',
#   'cultural',
#   'activity',
#   'in',
#   'school',
#   'are',
#   'struggling',
#   'with',
#   'social',
#   'anxiety',
#   'now'],
#  ['for',
#   'anyone',
#   'struggling',
#   'with',
#   '#anxiety',
#   'and',
#   'working',
#   'on',
#   'a',
#   'project',
#   "that's",
#   'stressing',
#   'you:',
#   "you're",
#   'ok.',
#   'step',
#   'back.',
#   'take',
#   'a',
#   'breath.',
#   'reassess.',
#   'if',
#   'you',
#   'need',
#   'to',
#   'read',
#   'the',
#   'manual,',
#   "it's",
#   'ok.',
#   'if',
#   'you',
#   'need',
#   'to',
#   're-do',
#   'some',
#   'work',
#   'to',
#   'correct',
#   'something,',
#   "it's",
#   'ok.',
#   'you',
#   'got',
#   'this.'],
#  ['this',
#   'week',
#   'is',
#   'already',
#   'starting',
#   'off',
#   'on',
#   'a',
#   'high',
#   'note,',
#   'and',
#   "it's",
#   'only',
#   'going',
#   'to',
#   'get',
#   'better',
#   '#thankful',
#   '#godisgood'],
#  ['i',
#   'could',
#   'really',
#   'use',
#   '$72',
#   'to',
#   'get',
#   'my',
#   "daughter's",
#   'anxiety',
#   'medication',
#   '$oniyamae'],
#  ['considering',
#   'sn.....easy',
#   'to',
#   'find,',
#   'very',
#   'effective.',
#   'otherwise',
#   'perhaps',
#   'bleach',
#   'and',
#   'vinegar',
#   'i',
#   'think',
#   'it',
#   'is.',
#   "there's",
#   'so',
#   'many',
#   'every',
#   'day',
#   'household',
#   'items',
#   'that',
#   'one',
#   'can',
#   'choose....just',
#   'a',
#   'matter',
#   'of',
#   'how',
#   'and',
#   'how',
#   'quickly/effectively.',
#   '#depression'],
#  ['music', 'helps', 'anxiety', 'fr'],
#  ['i',
#   'don’t',
#   'need',
#   'the',
#   'i',
#   'told',
#   'you',
#   'so’s….',
#   'i',
#   'just',
#   'need',
#   'to',
#   'get',
#   'through',
#   'this.',
#   '#anxiety'],
#  ['(t-16522)',
#   '#play',
#   'provides',
#   'unique',
#   'opportunities',
#   'to',
#   'enter',
#   'child’s',
#   'beautiful',
#   'world',
#   'which',
#   'helps',
#   'parents',
#   'to',
#   'forget',
#   'their',
#   '#anxiety',
#   'however',
#   'play',
#   'should',
#   'be',
#   'on',
#   'the',
#   'terms',
#   'and',
#   'wishes',
#   'of',
#   'the',
#   'child',
#   'learning',
#   'is',
#   'best',
#   'when',
#   'it',
#   'is',
#   'child',
#   'initiated',
#   'free',
#   'play'],
#  ['it',
#   'feels',
#   'good',
#   'to',
#   'be',
#   'still.',
#   '#affirmations',
#   '#anxiety',
#   '#happiness'],
#  ['i',
#   'love',
#   'having',
#   'anxiety',
#   'i’ll',
#   'just',
#   'be',
#   'sitting',
#   'here',
#   'doing',
#   'something',
#   'i',
#   'enjoy',
#   'and',
#   'suddenly',
#   'i',
#   'feel',
#   'sick',
#   'to',
#   'my',
#   'stomach',
#   'for',
#   'no',
#   'reason'],
#  ['happiness', 'is', 'the', 'greatest', 'good.', '#happiness'],
#  ['i',
#   'accept',
#   'my',
#   'flaws.',
#   '#affirmation',
#   '#affirmations',
#   '#positivemindset',
#   '#evolution',
#   '#inspirational',
#   '#inspiring',
#   '#dailymotivation',
#   '#mentalhealthawareness',
#   '#motivation',
#   '#sleep',
#   '#anxiety',
#   '#belove',
#   '#viral',
#   '#healthyliving',
#   '#life',
#   '#calming',
#   '#womenshealth',
#   '#art'],
#  ['you',
#   'need',
#   'to',
#   'stop',
#   'distracting',
#   'yourself',
#   'from',
#   'the',
#   'feelings',
#   'of',
#   'stress',
#   'and',
#   'anxiety.',
#   'this',
#   'only',
#   'makes',
#   'things',
#   'worse.',
#   'your',
#   'suppressing',
#   'your',
#   'emotions.',
#   'look',
#   'within.',
#   'ask',
#   'yourself',
#   'what',
#   'it',
#   'is',
#   'you',
#   'need',
#   'to',
#   'take',
#   'care',
#   'of.',
#   'something',
#   'is',
#   'being',
#   'neglected.',
#   'you’re',
#   'out',
#   'of',
#   'balance.'],
#  ["it's",
#   'good',
#   'to',
#   'reevaluate',
#   'the',
#   'people',
#   'around',
#   'you..',
#   'part',
#   'of',
#   'adulting',
#   '..',
#   '#life',
#   '#happiness',
#   '#peace'],
#  [';;;',
#   'i’ve',
#   'been',
#   'feeling',
#   'a',
#   'lil',
#   'bit',
#   'low',
#   'on',
#   'energy',
#   'since',
#   'coming',
#   'back',
#   'from',
#   'my',
#   'trip,',
#   'not',
#   'sure',
#   'why🤔🤔🤔',
#   'but',
#   'i',
#   'am',
#   'still',
#   '#grateful',
#   'i',
#   'was',
#   'able',
#   'to',
#   'push',
#   'my',
#   'self',
#   'to',
#   'do',
#   'a',
#   'lightweight',
#   'workout',
#   '#thankyou',
#   '#thankful',
#   '#blessed',
#   '1521444610',
#   '41020212210',
#   '151819212315',
#   '1510212921',
#   '#theuniverseisonmyside'],
#  ['should',
#   'be',
#   'a',
#   'banger',
#   'tomorrow.',
#   'hoping',
#   'to',
#   'see',
#   'the',
#   'ultra-instinct',
#   'holloway',
#   'again,',
#   'but',
#   'at',
#   'the',
#   'same',
#   'time',
#   'would',
#   'like',
#   'to',
#   'see',
#   'someone',
#   'other',
#   'than',
#   'max',
#   'contend',
#   'for',
#   'the',
#   'title.',
#   'either',
#   'way',
#   'the',
#   'fans',
#   'are',
#   '#blessed'],
#  ['life',
#   'is',
#   'too',
#   'short',
#   'to',
#   'be',
#   'anything',
#   'but',
#   'happy.',
#   'choose',
#   'joy,',
#   'and',
#   'let',
#   'it',
#   'fill',
#   'your',
#   'heart',
#   'every',
#   'day.',
#   '#happiness',
#   '#joyful'],
#  ['it’s', 'been', 'cloudy', 'with', 'a', 'chance', 'of', 'anxiety', ':(:'],
#  ['or',
#   'generalizations',
#   'about',
#   'any',
#   'particular',
#   'group',
#   'or',
#   'generation.',
#   'it',
#   'is',
#   'also',
#   'important',
#   'to',
#   'recognize',
#   'that',
#   'depression',
#   'is',
#   'a',
#   'serious',
#   'medical',
#   'condition',
#   'that',
#   'requires',
#   'professional',
#   'treatment',
#   'and',
#   'that',
#   'there',
#   'is',
#   'no',
#   'one-size-fits-all',
#   'explanation',
#   'for',
#   'its',
#   'causes',
#   'or',
#   'treatment.',
#   '#genz',
#   '#depression'],
#  ['what',
#   'i',
#   'understand',
#   'today(and',
#   "i'm",
#   'grateful',
#   'to',
#   'allah(swt))',
#   'is',
#   'that',
#   'finding',
#   'your',
#   'faith',
#   'and',
#   'your',
#   'purpose',
#   "doesn't",
#   'mean',
#   "you'll",
#   'never',
#   'have',
#   'doubts',
#   'anymore,',
#   'nor',
#   'does',
#   'it',
#   'mean',
#   "you'll",
#   'never',
#   'experience',
#   'void',
#   'or',
#   'anxiety',
#   'or',
#   'insecurities'],
#  ['i',
#   'chose',
#   'happiness',
#   'kindness',
#   '&amp;',
#   'the',
#   'word',
#   'of',
#   'god',
#   '.#thankful'],
#  ['anxiety.'],
#  ['i',
#   'hope',
#   'you',
#   'will',
#   'still',
#   'have',
#   'some',
#   'left',
#   'when',
#   'i',
#   'visit',
#   'first',
#   'thing',
#   '#easter',
#   '#sunday/as',
#   'soon',
#   'as',
#   'you',
#   'open',
#   'to',
#   'buy',
#   'as',
#   'many',
#   'as',
#   'i',
#   'can',
#   'afford',
#   '&amp;',
#   'then',
#   'i',
#   'will',
#   'take',
#   'them',
#   'to',
#   'distribute',
#   'at',
#   'my',
#   '#local',
#   '#hospital',
#   'to',
#   'bring',
#   'a',
#   'little',
#   'bit',
#   'of',
#   '#joy',
#   '&amp;',
#   '#happiness',
#   'to',
#   'the',
#   '#sick,',
#   '#ill,',
#   'etc',
#   '👍🙂',
#   '🕊️♥️🐣🐇💒🍫🥚🛐'],
#  ['depression',
#   'is',
#   'black',
#   'hole',
#   'sucks',
#   'everything',
#   'out',
#   'of',
#   'you.',
#   '#depression',
#   '#mentalhealth'],
#  ['now',
#   'is',
#   'all',
#   'you',
#   'have.',
#   'this',
#   'moment,',
#   'this',
#   'instant.',
#   'if',
#   'you',
#   'need',
#   'help',
#   'with',
#   'stress,',
#   'fear',
#   'and',
#   'worry.',
#   'reach',
#   'out.',
#   'i',
#   'do',
#   'coaching',
#   'to',
#   'help',
#   'address',
#   'anxiety',
#   'and',
#   'changing',
#   'your',
#   'mindset.',
#   '#stress',
#   '#anxiety',
#   '#tapping',
#   '#mindset',
#   '#helping',
#   '#coaching',
#   '#fastereft',
#   '#eutaptics',
#   '#braintraining'],
#  ['will',
#   'mdma',
#   'make',
#   'a',
#   'comeback',
#   'after',
#   'the',
#   '1960s?',
#   '"mdma-assisted',
#   'therapy',
#   'for',
#   'severe',
#   'ptsd"',
#   'link',
#   'to',
#   'research',
#   'below.',
#   '#mdma',
#   'and',
#   '#lsd',
#   'are',
#   'doing',
#   'great',
#   'in',
#   '#ptsd/#depression',
#   'studies',
#   '❤️',
#   '#psychology',
#   '#research',
#   '#lifestyle'],
#  ['practicing',
#   'daily',
#   'gratitude',
#   'can',
#   'help',
#   'us',
#   'to',
#   'create',
#   'abundance',
#   'in',
#   'our',
#   'lives',
#   'and',
#   'a',
#   'sense',
#   'of',
#   'peace',
#   'and',
#   'contentment.',
#   'what',
#   'three',
#   'things',
#   'are',
#   'you',
#   'grateful',
#   'for',
#   'today?',
#   '#gratitude',
#   '#happiness',
#   '#contentment',
#   '#abundance'],
#  ['exactly,',
#   "you've",
#   'seen',
#   'it',
#   'as',
#   'well',
#   'as',
#   'anyone',
#   'who',
#   "isn't",
#   'in',
#   'my',
#   'family',
#   'or',
#   'closer',
#   'friend.',
#   "i'm",
#   'trying',
#   'to',
#   'embrace',
#   'that',
#   'i',
#   'have',
#   'some',
#   'successes',
#   'and',
#   'at',
#   'least',
#   'some',
#   'things',
#   'i',
#   'can',
#   'do',
#   'now',
#   'that',
#   'make',
#   'me',
#   'less',
#   'helpless.',
#   "doesn't",
#   'mean',
#   "it's",
#   'not',
#   'hard,',
#   'but',
#   "i'm",
#   'grateful',
#   'to',
#   'be',
#   'here',
#   'instead',
#   'of',
#   'there.'],
#  ['my',
#   'anxiety',
#   'does',
#   'not',
#   'allow',
#   'me',
#   'to',
#   'get',
#   'into',
#   'a',
#   'full',
#   'van',
#   'at',
#   'all',
#   '...'],
#  ['#healing',
#   '#wellness',
#   '#fitness',
#   '#motivation',
#   '#happiness',
#   '#mindset',
#   '#support',
#   '#techsolutions',
#   '#youth',
#   '#nojudgement',
#   '#feelgood',
#   '#community',
#   '#scienceofwellness',
#   '#physicalfitness',
#   '#ncd',
#   '#obesity',
#   '#diabetes',
#   '#hypertension',
#   '#lifestyle',
#   'disorders'],
#  ['gm',
#   'everyone!',
#   'selflessness',
#   'is',
#   'not',
#   'about',
#   'sacrificing',
#   'your',
#   'own',
#   'happiness',
#   'for',
#   'others,',
#   "it's",
#   'about',
#   'finding',
#   'joy',
#   'in',
#   'making',
#   'others',
#   'happy.',
#   "let's",
#   'strive',
#   'to',
#   'be',
#   'selfless',
#   'every',
#   'day',
#   'and',
#   'make',
#   'the',
#   'world',
#   'a',
#   'brighter',
#   'place',
#   'for',
#   'everyone.',
#   'then',
#   'we',
#   'all',
#   '#wininlife',
#   '#selflessness',
#   '#kindness',
#   '#happiness'],
#  ["i'm",
#   'so',
#   'grateful',
#   'to',
#   'discover',
#   'kindred',
#   'spirits',
#   'in',
#   'this.',
#   'years',
#   'ago,',
#   'i',
#   "couldn't.",
#   'it',
#   'seemed',
#   'my',
#   'fellow',
#   'students',
#   'all',
#   'were',
#   'writing',
#   'what',
#   'amounted',
#   'to',
#   'book',
#   'reports,',
#   'not',
#   'asking',
#   'what',
#   'seemed',
#   'to',
#   'be',
#   'the',
#   'impt',
#   'questions,',
#   '&amp;',
#   'not',
#   'questioning',
#   'what',
#   'they',
#   'were',
#   'doing.',
#   '1/2'],
#  ["i'll",
#   'keep',
#   'everyone',
#   'updated',
#   'on',
#   'my',
#   'progress',
#   'as',
#   'i',
#   'continue',
#   'to',
#   'work',
#   'on',
#   'this',
#   'exciting',
#   'initiative.',
#   'please',
#   'follow',
#   'me',
#   'for',
#   'more',
#   'updates',
#   'and',
#   'help',
#   'me',
#   'spread',
#   'the',
#   'word',
#   'by',
#   'using',
#   'the',
#   'following',
#   'hashtags:',
#   '#programmer',
#   '#webapplication',
#   '#bot',
#   '#loneliness',
#   '#mentalhealth',
#   '#technology',
#   '#coding',
#   '#innovation'],
#  ['its',
#   'okay',
#   'to',
#   'not',
#   'be',
#   'okay.',
#   'i',
#   'am',
#   'going',
#   'through',
#   'a',
#   'lot',
#   'right',
#   'now',
#   'mentally,',
#   'as',
#   'depression',
#   'has',
#   'been',
#   'hitting',
#   'me',
#   'with',
#   'a',
#   'vengeance.',
#   'i',
#   'already',
#   'have',
#   'anxiety,',
#   'but',
#   'with',
#   'depression',
#   'resurfacing',
#   'and',
#   'being',
#   'added',
#   'into',
#   'the',
#   'equation,',
#   'i',
#   'am',
#   'struggling.'],
#  ['i',
#   'release',
#   'the',
#   'feeling',
#   'of',
#   'anxiety.',
#   'i',
#   'allow',
#   'the',
#   'feel',
#   'and',
#   'worry',
#   'to',
#   'slowly',
#   'melt',
#   'away.',
#   '#affirmations',
#   '#anxiety'],
#  ['expect',
#   'less,',
#   'accept',
#   'more!',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#sadquotes',
#   '#quotes',
#   '#sad',
#   '#love',
#   '#lovequotes',
#   '#broken',
#   '#brokenheart',
#   '#depressed',
#   '#lifequotes',
#   '#feelings',
#   '#like',
#   '#sadness',
#   '#sadedits',
#   '#depression',
#   '#poetry',
#   '#heartbroken',
#   '#sadquotespage',
#   '#alone'],
#  ['another',
#   'bought',
#   'of',
#   'insomnia,',
#   'mania,',
#   'and',
#   'pain..',
#   '#bpd',
#   '#bipolar2',
#   '#depression',
#   '#insomnia',
#   '#chronicallyill'],
#  ['man',
#   'i',
#   'used',
#   'to',
#   'live',
#   'in',
#   'the',
#   'uk',
#   'and',
#   'i',
#   'am',
#   'so',
#   'grateful',
#   'that',
#   'the',
#   'nhs',
#   'is',
#   'available',
#   'but',
#   'man',
#   'sometimes',
#   'they',
#   'are',
#   'fucked',
#   'up'],
#  ['andy',
#   'has',
#   'often',
#   'talked',
#   'about',
#   'her',
#   'mental',
#   'health',
#   'issues',
#   '(bipolar',
#   'hypomania/depression',
#   '&amp;',
#   'anxiety),',
#   'and',
#   'exhibits',
#   'obsessive',
#   'apophenia',
#   '—',
#   'seeing',
#   'a',
#   'connection',
#   'or',
#   'meaningful',
#   'pattern',
#   'between',
#   'unrelated',
#   'and/or',
#   'random',
#   'things.',
#   'andy',
#   'worked',
#   'closely',
#   'w/',
#   'freedom',
#   'convoy',
#   'protest',
#   'leaders',
#   'in',
#   'ottawa.'],
#  ['each',
#   'moment',
#   'of',
#   '#worry,',
#   '#anxiety',
#   'or',
#   '#stress',
#   'represents',
#   'lack',
#   'of',
#   'faith',
#   'in',
#   'miracles,',
#   'for',
#   'they',
#   'never',
#   'cease.'],
#  ['i',
#   'think',
#   'i',
#   'need',
#   'a',
#   'keyboardist',
#   'to',
#   'come',
#   'and',
#   'play',
#   'the',
#   'organs',
#   'for',
#   'me.',
#   '#depression'],
#  ['o', 'anxiety', 'olar🤣'],
#  ['insomnia,',
#   'hyper',
#   'vigilance,',
#   'anxiety,',
#   'fits',
#   'of',
#   'extreme',
#   'rage',
#   'or',
#   'sadness',
#   'that’s',
#   'what',
#   'i',
#   'got',
#   'going',
#   'on,',
#   'i',
#   'am',
#   'very',
#   'calm',
#   'around',
#   'my',
#   'wife',
#   'and',
#   'kid',
#   'i',
#   'never',
#   'expose',
#   'them',
#   'that',
#   'but',
#   'out',
#   'in',
#   'the',
#   'world',
#   'it’s',
#   'tough',
#   '..',
#   'that’s',
#   'why',
#   'i',
#   'keep',
#   'to',
#   'myself'],
#  ['i',
#   'think',
#   'my',
#   'anxiety',
#   'is',
#   'evolving',
#   'to',
#   'make',
#   'my',
#   'life',
#   'even',
#   'more',
#   'miserable',
#   '😭'],
#  ['your',
#   'peace',
#   'is',
#   'everything.',
#   'protect',
#   'it',
#   'at',
#   'all',
#   'cost.',
#   'stay',
#   'drama',
#   'free.',
#   '#anxiety',
#   '#depression',
#   '#mentalhealth',
#   '#mentalhealthawareness',
#   '#mentalhealthmatters',
#   '#positivity',
#   '#positivevibesonly',
#   '#positivequotes',
#   '#positivethinking',
#   '#positiveenergy',
#   '#positivethoughts'],
#  ['went',
#   'out',
#   'w',
#   'bestie,',
#   'went',
#   'to',
#   'brekkie',
#   'w',
#   'bestie',
#   '&amp;',
#   'fting',
#   'bestie',
#   'when',
#   'she',
#   'got',
#   'home',
#   'i',
#   'wonder',
#   'if',
#   'we',
#   'have',
#   'separation',
#   'anxiety',
#   'lol'],
#  ['you', "can't", 'simply', 'wish', '#depression', 'away.'],
#  ['true',
#   'happiness',
#   'is',
#   'in',
#   'realising',
#   'that',
#   'you',
#   'are',
#   'priceless',
#   'which',
#   'money',
#   'can’t',
#   'buy.',
#   'you',
#   'are',
#   'higher',
#   'than',
#   'anything',
#   'material.',
#   '#godmorningthurday',
#   '#happiness',
#   '#spirituality'],
#  ['another',
#   'day',
#   'another',
#   'opportunity;',
#   'blessed',
#   'is',
#   'an',
#   'understatement',
#   '#thankful'],
#  ['i',
#   'accepted',
#   'it',
#   'already',
#   'but',
#   'it',
#   'still',
#   'makes',
#   'me',
#   'sad.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#sadquotes',
#   '#quotes',
#   '#sad',
#   '#love',
#   '#lovequotes',
#   '#broken',
#   '#brokenheart',
#   '#depressed',
#   '#lifequotes',
#   '#feelings',
#   '#like',
#   '#sadness',
#   '#sadedits',
#   '#depression',
#   '#poetry',
#   '#heartbroken',
#   '#sadquotespage',
#   '#alone'],
#  ['investing',
#   'in',
#   'myself',
#   'is',
#   'the',
#   'best',
#   'decision',
#   'i',
#   'ever',
#   'made.',
#   'you',
#   "can't",
#   'put',
#   'a',
#   'price',
#   'on',
#   'your',
#   '#health,',
#   'your',
#   '#wealth,',
#   'or',
#   'your',
#   '#happiness'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'really',
#   'want',
#   'to',
#   'be',
#   'evaluated',
#   'by',
#   'a',
#   'psychiatrist',
#   'for',
#   'things',
#   'outside',
#   'of',
#   'my',
#   'depression',
#   'and',
#   'anxiety.',
#   'so',
#   'much',
#   'crap',
#   'like',
#   'this',
#   'and',
#   'how',
#   'i',
#   'view',
#   'myself/my',
#   'ability',
#   'to',
#   'have',
#   'friends',
#   'and',
#   'be',
#   'part',
#   'of',
#   'a',
#   'group',
#   'are',
#   'decidedly',
#   'very',
#   'much',
#   'not',
#   'neurotypical.'],
#  ['lost',
#   '150',
#   'lp',
#   'today',
#   'someone',
#   'cheer',
#   'me',
#   'up',
#   '#sad',
#   '#depressed',
#   '#emo'],
#  ['i',
#   'woke',
#   'up.i',
#   'have',
#   'clothes',
#   'to',
#   'wear.i',
#   'have',
#   'running',
#   'water.i',
#   'have',
#   'food',
#   'to',
#   'eat.i',
#   'have',
#   'roof',
#   'over',
#   'my',
#   'head.',
#   'life',
#   'is',
#   'good.i',
#   'am',
#   'thankful.🙏🏻',
#   '#gratitudeistheattitude',
#   '#thankful',
#   '#blessedandgrateful'],
#  ["jaan'",
#   'is',
#   'not',
#   'just',
#   'a',
#   'word,',
#   "it's",
#   'a',
#   'package',
#   'of',
#   'respect,',
#   'priority',
#   'and',
#   'a',
#   'lot',
#   'of',
#   'care',
#   '&amp;',
#   'love.❤️',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#sadquotes',
#   '#quotes',
#   '#sad',
#   '#love',
#   '#lovequotes',
#   '#broken',
#   '#brokenheart',
#   '#depressed',
#   '#lifequotes',
#   '#feelings',
#   '#like',
#   '#sadness',
#   '#sadedits',
#   '#depression',
#   '#poetry',
#   '#heartbroken',
#   '#sadquotespage',
#   '#alone'],
#  ['so', '#thankful.', 'still', 'sending', 'prayers'],
#  ['morning',
#   'comes,',
#   "it's",
#   'time',
#   'to',
#   'be',
#   'more',
#   'excited',
#   'to',
#   'start',
#   'the',
#   'day.',
#   "it's",
#   'sunny',
#   'day,',
#   'hope',
#   'your',
#   'mood',
#   'is',
#   'bright.',
#   "don't",
#   'forget',
#   'to',
#   'be',
#   'grateful.',
#   'have',
#   'a',
#   'nice',
#   'day.'],
#  ['why',
#   'do',
#   'you',
#   'think',
#   'the',
#   '#2ndamendment',
#   'is',
#   'more',
#   'important',
#   'than',
#   'a',
#   "child's",
#   'right',
#   'to',
#   '#life,',
#   '#liberty',
#   '&amp;',
#   'the',
#   'pursuit',
#   'of',
#   '#happiness?',
#   'those',
#   'rights',
#   'are',
#   'in',
#   'the',
#   'second',
#   'paragraph',
#   'of',
#   'the',
#   'first',
#   'article',
#   'in',
#   'the',
#   'declaration',
#   'of',
#   'independence',
#   'which',
#   'comes',
#   'long',
#   'before',
#   'the',
#   'second',
#   'amendment.'],
#  ['springtime',
#   'brings',
#   'happy',
#   'beginnings',
#   'and',
#   'blooming',
#   'flowers.',
#   "let's",
#   'embrace',
#   'the',
#   'sunshine,',
#   'enjoy',
#   'the',
#   'greenery,',
#   'and',
#   'create',
#   'our',
#   'own',
#   'spring',
#   'story',
#   '🌷☀️',
#   '#springtime',
#   '#newbeginnings',
#   '#happiness'],
#  ['you',
#   'might',
#   'be',
#   'a',
#   'people',
#   'pleaser',
#   'if',
#   'you',
#   'use',
#   'a',
#   'smiley',
#   'face',
#   'at',
#   'the',
#   'end',
#   'of',
#   'text',
#   'messages.',
#   '☺️',
#   '#peoplepleaser',
#   '#anxiety'],
#  ['grateful.',
#   'i’m',
#   '31',
#   'now.',
#   'i',
#   'enjoy',
#   'my',
#   'fathers',
#   'garden',
#   'alot',
#   'more',
#   'than',
#   'when',
#   'i',
#   'was',
#   'a',
#   'kid.',
#   'when',
#   'i',
#   'was',
#   'a',
#   'kid.',
#   'i',
#   'would',
#   'never',
#   'be',
#   'in',
#   'the',
#   'garden',
#   'cuz',
#   'i’m',
#   'between',
#   'florence',
#   'and',
#   'manchester'],
#  ['there’s',
#   'so',
#   'much',
#   'to',
#   'my',
#   'story',
#   'and',
#   'i',
#   'tell',
#   'it',
#   'because',
#   'i',
#   'never',
#   'want',
#   'anyone',
#   'to',
#   'ever',
#   'feel',
#   'as',
#   'alone',
#   'as',
#   'i',
#   'have.',
#   'my',
#   'life',
#   'has',
#   'been',
#   'far',
#   'from',
#   'easy',
#   'but',
#   'i’m',
#   'still',
#   'here.',
#   'i',
#   'do',
#   'what',
#   'i',
#   'can',
#   'for',
#   'those',
#   'struggling',
#   'with',
#   '#anxiety',
#   '#depression',
#   'or',
#   'any',
#   '#mentalhealth',
#   'issue',
#   'because',
#   'i',
#   'know',
#   'how',
#   'it',
#   'feels'],
#  ['finding', 'joy', 'in', 'the', 'simple', 'things', '#happiness'],
#  ['mostly',
#   'i',
#   'get',
#   'a',
#   'lot',
#   'of',
#   'anxiety',
#   'vibes',
#   'from',
#   'ms',
#   'truss.'],
#  ['i',
#   'doubt',
#   'you',
#   'would',
#   'see',
#   'this',
#   'but',
#   'if',
#   'you',
#   'do',
#   'pls,',
#   'i',
#   'need',
#   'help',
#   'to',
#   'undergo',
#   'retina',
#   'surgery.',
#   'my',
#   'sight',
#   'is',
#   'deteriorating',
#   'and',
#   'i',
#   "don't",
#   'have',
#   'finds',
#   'to',
#   'treat',
#   'myself.',
#   'i',
#   'know',
#   'you',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'people',
#   'asking',
#   'for',
#   'aid',
#   'but',
#   'please',
#   'consider',
#   'me.',
#   '#helpless',
#   '#depressed'],
#  ['it’s',
#   'a',
#   'honor',
#   'to',
#   'be',
#   'looked',
#   'up',
#   'to',
#   'and',
#   'used',
#   'as',
#   'an',
#   'example',
#   'for',
#   'elgin’s',
#   'finest.#thankful',
#   '#utd💜💜'],
#  ['live',
#   'up',
#   'to',
#   'what',
#   'you',
#   'say',
#   '#burden',
#   '#depressed',
#   '#depression',
#   '#depressionhelp',
#   '#disappointed',
#   '#goodbyes',
#   '#heartbreak',
#   '#ill',
#   '#lonely',
#   '#mentalhealth',
#   '#mentalillness',
#   '#missing',
#   '#overthinker',
#   '#socialanxiety',
#   '#unstable',
#   '#adhd',
#   '#mentallyilltwt'],
#  ['i',
#   'am',
#   'free',
#   'from',
#   'jealousy.',
#   '#affirmation',
#   '#affirmations',
#   '#viral',
#   '#business',
#   '#affirmationnation',
#   '#wellbeing',
#   '#bekind',
#   '#dailyquotes',
#   '#fittip',
#   '#depression',
#   '#affirmationoftheday',
#   '#relationship',
#   '#lawofattraction',
#   '#healing',
#   '#encouragement',
#   '#goals',
#   '#words'],
#  ['from',
#   'a',
#   'simple',
#   'act',
#   'of',
#   'kindness',
#   'a',
#   'tree',
#   'of',
#   'happiness',
#   'will',
#   'grow.',
#   '#being_human',
#   '#beinghuman',
#   '#lifeisbeautiful',
#   '#happiness'],
#  ['i', 'want', 'to', 'die.', "i'll", 'kill', 'myself', '.', '#depression'],
#  ['awesome,',
#   "i'm",
#   'on',
#   'the',
#   'other',
#   'side',
#   'of',
#   'the',
#   'lsu',
#   'parents,',
#   'i',
#   'can',
#   'see',
#   'their',
#   'anxiety',
#   'grow',
#   'in',
#   'real',
#   'time!'],
#  ['this',
#   'is',
#   'the',
#   'day',
#   'my',
#   'nigel',
#   'is',
#   'getting',
#   'a',
#   'full-body',
#   'short-hair',
#   'groom!',
#   'gave',
#   'him',
#   'his',
#   'anxiety',
#   'meds',
#   'to',
#   'help',
#   'him',
#   'get',
#   'through',
#   'it.',
#   'will',
#   'take',
#   'him',
#   'for',
#   'a',
#   'walk',
#   'before',
#   'we',
#   'leave',
#   'too.',
#   "it's",
#   'an',
#   'all-day',
#   'ordeal',
#   'lol.'],
#  ['claudia',
#   'k',
#   'white',
#   'dx',
#   'adhd,',
#   'ptsd,',
#   'insomnia.',
#   'anxiety/panic!',
#   '20+',
#   'years',
#   'historical',
#   'diagnoses',
#   'and',
#   'treatment',
#   'social',
#   'security',
#   'disablity',
#   'retirement.🇱🇷',
#   '37',
#   'year',
#   'member',
#   'alcoholics',
#   'anonymous',
#   'second',
#   'generation',
#   '#aaws',
#   '#alanon',
#   '#alateen',
#   '#nami',
#   '#gregstevens',
#   '#randalgaither',
#   '#salsonclinic',
#   'biden',
#   'regime…'],
#  ['this', 'is', 'giving', 'me', 'anxiety'],
#  ['aj', 'seriously', 'anxiety', 'horhi', 'ye', 'drama', 'dekh', 'k'],
#  ['sometimes',
#   'i',
#   'find',
#   'this',
#   'world',
#   'very',
#   'bitter',
#   'and',
#   'the',
#   'upcoming',
#   'bitterness',
#   'really',
#   'make',
#   'me',
#   'worry.',
#   '#life',
#   '#suicide',
#   '#depression'],
#  ['depression',
#   'and',
#   'anxiety',
#   'are',
#   'evil',
#   '&amp;',
#   'kill.',
#   'fighting',
#   'everyday',
#   'is',
#   'exhausting.',
#   'i',
#   "don't",
#   'know',
#   'what',
#   'else',
#   'to',
#   'do',
#   'now,',
#   'i',
#   'only',
#   'have',
#   'so',
#   'much',
#   'strength',
#   '#mentalhealth',
#   '#mentalillness',
#   '#bipolar',
#   '#depression',
#   '#anxiety'],
#  ['i',
#   'am',
#   'feeling',
#   'incredibly',
#   'low',
#   'since',
#   'the',
#   'past',
#   '2',
#   'days.',
#   'im',
#   'not',
#   'sure',
#   'how',
#   'to',
#   'go',
#   'about',
#   'things',
#   'anymore.',
#   'just',
#   'hating',
#   'the',
#   'uncertainty',
#   'and',
#   'the',
#   'fact',
#   'that',
#   'ive',
#   'reached',
#   'nowhere',
#   'i',
#   'wanted',
#   'to.',
#   'finding',
#   'it',
#   'difficult',
#   'to',
#   'do',
#   'anything',
#   'too',
#   '#depression',
#   '#lowmoods'],
#  ['love',
#   'this',
#   'little',
#   'game',
#   'where',
#   'my',
#   'husband',
#   'loses',
#   'his',
#   'wallet.',
#   'wait,',
#   'it’s',
#   'not',
#   'lost.',
#   'he',
#   'just',
#   'doesn’t',
#   'know',
#   'where',
#   'it',
#   'is.',
#   '#marriage',
#   '#anxiety'],
#  ['life',
#   'is',
#   'too',
#   'short',
#   'to',
#   'waste',
#   'time',
#   'on',
#   'things',
#   'that',
#   "don't",
#   'matter.',
#   'focus',
#   'on',
#   'what',
#   'truly',
#   'makes',
#   'you',
#   'happy',
#   'and',
#   'fulfilled,',
#   'and',
#   'let',
#   'go',
#   'of',
#   'everything',
#   'else.',
#   '#priorities',
#   '#happiness',
#   '#fulfillment'],
#  ['watching',
#   'documentary',
#   'on',
#   '#netflix.',
#   'my',
#   '#anxiety',
#   'is',
#   'bad,',
#   'but',
#   'i',
#   'can’t',
#   'imagine',
#   'the',
#   'pressure',
#   'he',
#   'has',
#   'been',
#   'under',
#   'and',
#   'the',
#   'complete',
#   'change',
#   'in',
#   'his',
#   'life.',
#   'i’ve',
#   'thought',
#   'i',
#   'was',
#   'dying',
#   'at',
#   'least',
#   '3',
#   'times',
#   'and',
#   'it',
#   'was',
#   'a',
#   'panic',
#   'attack.',
#   'thankyou',
#   'for',
#   'your',
#   'honesty',
#   '#lewiscapaldi',
#   '*hugs',
#   'dude*'],
#  ['#anxiety',
#   '#depression',
#   '😭',
#   'lord',
#   'i',
#   "can't",
#   'help',
#   'it',
#   'anymore'],
#  ['claudia',
#   'k',
#   'white',
#   'dx',
#   'adhd,',
#   'ptsd,',
#   'insomnia.',
#   'anxiety/panic!',
#   '20+',
#   'years',
#   'historical',
#   'diagnoses',
#   'and',
#   'treatment',
#   'social',
#   'security',
#   'disablity',
#   'retirement.🇱🇷',
#   '37',
#   'year',
#   'member',
#   'alcoholics',
#   'anonymous',
#   'second',
#   'generation',
#   '#aaws',
#   '#alanon',
#   '#alateen',
#   '#nami',
#   '#gregstevens',
#   '#randalgaither',
#   '#salsonclinic',
#   'biden',
#   'regime…'],
#  ['lol',
#   '@',
#   '"all',
#   'existing',
#   'comorbidities',
#   'must',
#   'be',
#   'resolved".',
#   'because',
#   'like',
#   'the',
#   'two',
#   'most',
#   'common',
#   'mental',
#   'illnesses,',
#   'anxiety',
#   'and',
#   'depression,',
#   'are',
#   'just',
#   'so',
#   'easily',
#   'resolved',
#   'and',
#   'totally',
#   'not',
#   'life-long',
#   'struggles'],
#  ['#anxiety',
#   'plus',
#   'a',
#   'very',
#   'packed',
#   'train',
#   '=',
#   'not',
#   'a',
#   'good',
#   'combination',
#   '#travel',
#   '#train'],
#  ['#thismorning',
#   'it',
#   'is',
#   'not',
#   '#anxiety,',
#   'it',
#   'is',
#   '#stress',
#   'caused',
#   'by',
#   'deliberate',
#   'conservative',
#   'policies,',
#   'to',
#   'impoverish',
#   '#england.',
#   '#toriescostlives',
#   '#toriesdestroyingournhs',
#   '#nhs',
#   '#generalelectionnow',
#   '#toriesout280',
#   '#conservatives',
#   '#trumpcrimefamily',
#   '#torycriminals'],
#  ['life',
#   'is',
#   'too',
#   'short',
#   'to',
#   'not',
#   'do',
#   'what',
#   'makes',
#   'you',
#   'happy.',
#   'find',
#   'your',
#   'passion',
#   'and',
#   'pursue',
#   'it',
#   'relentlessly.',
#   '#followyourdreams',
#   '#happiness'],
#  ['thankful',
#   'for',
#   'another',
#   'day',
#   'another',
#   'opportunity',
#   'to',
#   'get',
#   'it',
#   'right.',
#   '#thankful',
#   '#blessed'],
#  ['i',
#   "can't",
#   'wait',
#   'to',
#   'get',
#   'the',
#   'hell',
#   'out.',
#   "i'll",
#   'kill',
#   'myself',
#   '.',
#   '#anxiety'],
#  ['#depression...',
#   'the',
#   '#1',
#   'side',
#   'effect',
#   'of',
#   'taking',
#   'an',
#   'ssri',
#   'antidepressant----------',
#   'suicide'],
#  ['when',
#   'you',
#   'remove',
#   'the',
#   'pressure',
#   'and',
#   'expectations,',
#   'you',
#   'allow',
#   'yourself',
#   'to',
#   'start.',
#   'what',
#   'mini',
#   'habit(s)',
#   'will',
#   'you',
#   'start',
#   'today?',
#   '#follow',
#   'for',
#   'infusing',
#   '#happiness',
#   'and',
#   'good',
#   'health',
#   'in',
#   'your',
#   'life.',
#   '#habits',
#   '#lifecoaching',
#   '#lifecoach',
#   '#motivationalpost',
#   '#motivation',
#   '#wisdom'],
#  ['"fight',
#   'with',
#   'depression-intruder',
#   'and',
#   'prove',
#   'to',
#   'god',
#   'that',
#   'you',
#   'are',
#   'his',
#   'hero-warrior."',
#   '~sri',
#   'chinmoy',
#   '#depression',
#   '#innerpeace'],
#  ['well',
#   'my',
#   'injection',
#   'sucked',
#   'and',
#   'now',
#   'i',
#   'am',
#   'super',
#   'sick',
#   'from',
#   'it',
#   'and',
#   "can't",
#   'sleep.',
#   '😔',
#   '#mentalhealth',
#   '#mentalillness',
#   '#bpd',
#   '#ptsd',
#   '#ibd',
#   '#ibs',
#   '#crohnsdisease',
#   '#bipolar',
#   '#chronicpain',
#   '#chronicillness',
#   '#anxiety',
#   '#depression'],
#  ['you',
#   'have',
#   'a',
#   'golden',
#   'heart',
#   'and',
#   'soul',
#   'you’re',
#   'giving',
#   'out',
#   'to',
#   'the',
#   'street,',
#   'bless',
#   'you',
#   'if',
#   'you',
#   'ever',
#   'gave',
#   'me',
#   'anything',
#   'i',
#   'will',
#   'reject',
#   'it!',
#   'show',
#   'me',
#   'how',
#   'to',
#   'make',
#   'bread,',
#   'no',
#   'give',
#   'me',
#   'bread',
#   '#depression',
#   '#depressed'],
#  ['good',
#   'morning',
#   'to',
#   'some',
#   'goodnight',
#   'to',
#   'others.',
#   'wherever',
#   'you',
#   'may',
#   'be',
#   'at',
#   'this',
#   'point',
#   'there',
#   'is',
#   'always',
#   'room',
#   'for',
#   'progress.',
#   'keep',
#   'your',
#   'chin',
#   'up',
#   'and',
#   'make',
#   'someone',
#   'smile.',
#   'keep',
#   'your',
#   'ears',
#   'open',
#   '#peace',
#   '#love',
#   '#happiness',
#   '#uniteforchange.'],
#  ['i’m',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'devastating',
#   'loss',
#   'and',
#   'grateful',
#   'for',
#   'this',
#   'wonderful',
#   'opportunity',
#   'for',
#   'isaiah.❤️'],
#  ['i’ve',
#   'struggled',
#   'with',
#   'saying',
#   'no',
#   'to',
#   'ppl',
#   'but',
#   'babi',
#   'when',
#   'i',
#   'tell',
#   'you',
#   'that’s',
#   'all',
#   'i',
#   'been',
#   'saying',
#   'is',
#   'no',
#   'to',
#   'ppl',
#   'that',
#   'want',
#   'or',
#   'need',
#   'me',
#   'to',
#   'do',
#   'something',
#   '&amp;',
#   'been',
#   'saying',
#   'yes',
#   'to',
#   'ppl',
#   'that',
#   'want',
#   'to',
#   'do',
#   'sumthin',
#   'for',
#   'me',
#   '&amp;',
#   'when',
#   'i',
#   'tell',
#   'you',
#   'it’s',
#   'the',
#   'best',
#   'feeling',
#   '🥰',
#   '#thankful'],
#  ['my', 'anxiety', 'has', 'never', 'been', 'this', 'bad', 'before'],
#  ['at',
#   'some',
#   'stages',
#   'of',
#   'your',
#   'life',
#   'you',
#   'will',
#   'deal',
#   'with',
#   'things',
#   'and',
#   'at',
#   'others',
#   'you',
#   'are',
#   'overwhelmed',
#   'with',
#   '#misery',
#   'and',
#   '#anxiety.'],
#  ['the',
#   'best',
#   'way',
#   'to',
#   'eliminate',
#   'social',
#   'anxiety',
#   'is',
#   'to',
#   'participate',
#   'in',
#   'video',
#   'game',
#   'toxicity',
#   'honest',
#   'to',
#   'god',
#   'it',
#   'helped',
#   'me',
#   'so',
#   'much',
#   'im',
#   'being',
#   'so',
#   'serious😭'],
#  ['im',
#   'so',
#   'dumb',
#   '😭',
#   'genuinely',
#   'grateful',
#   'for',
#   'my',
#   'friends',
#   'for',
#   'helping',
#   'me'],
#  ['its',
#   'kinda',
#   'crazy',
#   'some',
#   'people',
#   'don’t',
#   'wake',
#   'up',
#   'with',
#   'depression',
#   'and',
#   'anxiety',
#   'everyday'],
#  ['do',
#   'you',
#   'feel',
#   'on',
#   'edge',
#   'at',
#   'work?',
#   'are',
#   'you',
#   'irritable',
#   'or',
#   'easily',
#   'annoyed',
#   'in',
#   'meetings?',
#   'are',
#   'you',
#   'having',
#   'trouble',
#   'sleeping?',
#   'have',
#   'you',
#   'experienced',
#   'changes',
#   'in',
#   'appetite',
#   'or',
#   'sense',
#   'your',
#   'motivation',
#   'has',
#   'been',
#   'slipping?',
#   '2/',
#   '#anxiety',
#   '#depression'],
#  ['my', 'anxiety', 'will', 'probably', 'go', 'boom😭', '☄'],
#  ['“stop',
#   'giving',
#   'other',
#   'people',
#   'the',
#   'power',
#   'to',
#   'control',
#   'your',
#   'happiness,',
#   'your',
#   'mind,',
#   'and',
#   'your',
#   'life.',
#   'if',
#   'you',
#   "don't",
#   'take',
#   'control',
#   'of',
#   'yourself',
#   'and',
#   'your',
#   'own',
#   'life,',
#   'someone',
#   'else',
#   'is',
#   'bound',
#   'to',
#   'try”',
#   '#quotes',
#   '#happiness'],
#  ['mental',
#   'health',
#   'workers',
#   'are',
#   'not',
#   'hearing',
#   'me.nobody',
#   'is',
#   'truly',
#   'deeply',
#   'listening',
#   'to',
#   'me.they',
#   'are',
#   'not',
#   'giving',
#   'me',
#   'time',
#   'to',
#   'talk.they',
#   'do',
#   'all',
#   'the',
#   'talking.',
#   'please',
#   'hear',
#   'me.',
#   'guide',
#   'me',
#   'with',
#   'questions',
#   'to',
#   'help',
#   'you',
#   'understand',
#   'my',
#   'pain.',
#   'i',
#   'don’t',
#   'think',
#   'they',
#   'really',
#   'care',
#   'to',
#   'know.',
#   '#depression',
#   '#mentalhealth'],
#  ['my', 'chronic', 'anxiety'],
#  ['sometimes',
#   'we',
#   'need',
#   'to',
#   'put',
#   'a',
#   'little',
#   'effort',
#   'into',
#   'happiness,',
#   'but',
#   'it',
#   'sure',
#   'is',
#   'worth',
#   'it.',
#   '#happiness'],
#  ['nobody',
#   'is',
#   'listening.',
#   'america',
#   'has',
#   'many',
#   'enemies',
#   '&amp;',
#   'good',
#   'time',
#   'friends',
#   'because',
#   'of',
#   'this',
#   'administration',
#   '&amp;',
#   'previous',
#   'occupants.',
#   'biden',
#   'doesn’t',
#   'have',
#   'the',
#   'wherewithal',
#   'to',
#   'handle',
#   'this.',
#   'there’s',
#   'going',
#   'to',
#   'be',
#   'as',
#   'many',
#   'knives',
#   'in',
#   'the',
#   'back',
#   'as',
#   'well',
#   'as',
#   'full',
#   'frontal',
#   'assault',
#   'on',
#   'our',
#   'economy.',
#   '#depression'],
#  ['dude,',
#   'yall',
#   'hiring',
#   'teams',
#   'be',
#   'bs.',
#   'just',
#   'now',
#   'hearing',
#   'sum',
#   'from',
#   'january.',
#   'this',
#   'why',
#   'i',
#   'slowed',
#   'up',
#   'on',
#   'yall.',
#   'feel',
#   'like',
#   'i',
#   'need',
#   'time',
#   'to',
#   'focus',
#   'and',
#   'get',
#   'ready',
#   'for',
#   'my',
#   'degree.',
#   'ima',
#   'finish',
#   'this',
#   'degree.',
#   'its',
#   'important.',
#   'i',
#   'would',
#   'prefer',
#   'to',
#   'not',
#   'have',
#   'added',
#   'anxiety',
#   'from',
#   'a',
#   'corp.',
#   'thats',
#   'gone',
#   'play',
#   'with',
#   'me.'],
#  ['good',
#   'morning!',
#   '🙏',
#   'after',
#   'two',
#   'weeks',
#   'of',
#   'straight',
#   'aral,',
#   'sanity',
#   'break',
#   'today',
#   'with',
#   'my',
#   'boys✨',
#   'so',
#   'grateful',
#   'for',
#   'my',
#   'bar',
#   'buddies',
#   'taking',
#   'notes',
#   'and',
#   'providing',
#   'for',
#   'todays',
#   'lecture',
#   '🙏',
#   'this',
#   'is',
#   'why',
#   'you',
#   'never',
#   'underestimate',
#   'a',
#   'solid',
#   'support',
#   'group',
#   '\U0001faf6🏼',
#   '#hernandobar2023',
#   '#hernandoit'],
#  ['"life',
#   'is',
#   'too',
#   'short',
#   'to',
#   'waste',
#   'time',
#   'on',
#   'things',
#   'that',
#   "don't",
#   'bring',
#   'you',
#   'joy.',
#   'focus',
#   'on',
#   'the',
#   'things',
#   'that',
#   'make',
#   'you',
#   'happy,',
#   'surround',
#   'yourself',
#   'with',
#   'positive',
#   'people,',
#   'and',
#   'never',
#   'stop',
#   'pursuing',
#   'your',
#   'passions.',
#   '#happiness',
#   '#positivity',
#   '#passion',
#   '#livelifetothefullest"'],
#  ['i',
#   'forgot',
#   'deodorant',
#   'today.',
#   'i',
#   'am',
#   'not',
#   'leaving',
#   'my',
#   'office',
#   'for',
#   'fear',
#   'of',
#   'funk.',
#   'now',
#   'i’m',
#   'sitting',
#   'in',
#   'my',
#   'office',
#   'with',
#   'anxiety',
#   'about',
#   'funkiness,',
#   'which',
#   'is',
#   'making',
#   'me',
#   'warm.',
#   'this',
#   'is',
#   'a',
#   'no-win',
#   'situation.'],
#  ['hdfc',
#   'bank',
#   'giving',
#   'as',
#   'torture',
#   'credit',
#   'card',
#   'department',
#   'karthick',
#   'richmond',
#   'road',
#   'bangalore',
#   'we',
#   'lost',
#   'everything',
#   'from',
#   'covid',
#   "don't",
#   'have',
#   'money',
#   'we',
#   'want',
#   'to',
#   'die',
#   'he',
#   'giving',
#   'torture',
#   'mentally',
#   '#hdfc',
#   '#highcourt',
#   '#humanrights',
#   '#narendramodi',
#   '#rbi',
#   '#covid',
#   '#hdfcbank',
#   '#amitshah',
#   '#indian',
#   '#depression',
#   '#'],
#  ['man', 'u', 'don’t', 'know', 'how', 'grateful', 'i', 'am', 'right', 'now'],
#  ['leaving',
#   'the',
#   'house',
#   'and',
#   'coming',
#   'back',
#   'safe',
#   'and',
#   'sound',
#   'is',
#   'a',
#   'blessing.',
#   "i'm",
#   'grateful',
#   '🙏🏾'],
#  ['“…cause',
#   "it's",
#   'hard',
#   'to',
#   'be',
#   'sad',
#   'when',
#   '"backstreet’s',
#   'back”',
#   'alright?”',
#   '-',
#   'what',
#   'i',
#   'said',
#   'at',
#   'the',
#   'end',
#   'of',
#   'a',
#   'sentence',
#   'where',
#   'i',
#   'was',
#   'giving',
#   'actual',
#   'mental',
#   'health',
#   'advice',
#   'to',
#   'someone',
#   'today.',
#   '#mentalhealth',
#   '#depression',
#   '#backstreetboys'],
#  ['life',
#   'is',
#   'too',
#   'short',
#   'to',
#   'waste',
#   'time',
#   'on',
#   'things',
#   'that',
#   "don't",
#   'matter.',
#   'focus',
#   'on',
#   'what',
#   'makes',
#   'you',
#   'happy',
#   'and',
#   'fulfilled,',
#   'and',
#   'let',
#   'go',
#   'of',
#   'the',
#   'rest.',
#   '#lifegoals',
#   '#happiness'],
#  ['life',
#   'is',
#   'too',
#   'short',
#   'to',
#   'not',
#   'dance',
#   'in',
#   'the',
#   'ra',
#   'in',
#   '🌧',
#   '#happiness'],
#  ['seeing',
#   'all',
#   'these',
#   'pregnancy',
#   'announcements',
#   'from',
#   'yesterday',
#   'is',
#   'making',
#   'me',
#   'depressed',
#   '😔',
#   '#depression'],
#  ['you', "can't", 'simply', 'wish', '#depression', 'away.'],
#  ['have',
#   'you',
#   'talked',
#   'to',
#   'anyone',
#   'about',
#   'how',
#   'you',
#   'feel?',
#   '#mentalhealth',
#   '#depression'],
#  ['thank',
#   'you',
#   'lord',
#   'for',
#   'blessing',
#   'me',
#   'with',
#   'another',
#   'day',
#   '#thankful',
#   '#godisgreat'],
#  ['you💘',
#   'are',
#   'capable;',
#   'remember',
#   'to',
#   'please',
#   '🙏🏽:',
#   'be',
#   'patient',
#   'and',
#   'listen🙇🏻',
#   '#happiness'],
#  ['there’s',
#   'no',
#   'greater',
#   'stress',
#   'than',
#   'when',
#   'you’re',
#   'singing',
#   'and',
#   'you',
#   'dad',
#   'after',
#   'goes',
#   '“you',
#   'need',
#   'to',
#   'sing',
#   'louder”',
#   'i’m',
#   'pushing',
#   'it',
#   'out',
#   'with',
#   'my',
#   'chest',
#   'but',
#   'it',
#   'will',
#   'not',
#   'come',
#   'out!!!',
#   '#anxiety',
#   '#stagefright'],
#  ['believe',
#   'in',
#   'yourself.',
#   '💙🙏🏼',
#   'you',
#   'can',
#   'accomplish',
#   'anything',
#   'you',
#   'put',
#   'your',
#   'mind',
#   'too.',
#   '❤️❤️',
#   '#beautiful',
#   '#emotional',
#   '#happiness',
#   '#love',
#   '#sweetmessage'],
#  ['did',
#   'something',
#   'happen',
#   'to',
#   'make',
#   'you',
#   'start',
#   'feeling',
#   'this',
#   'way?',
#   '#mentalhealth',
#   '#depression'],
#  ['trumps',
#   'indictment',
#   'is',
#   'a',
#   'distraction',
#   'and',
#   'is',
#   'a',
#   'weak',
#   'attempt',
#   'at',
#   'suppressing',
#   'an',
#   'opponent.',
#   'there’s',
#   'a',
#   'lot',
#   'more',
#   'at',
#   'play',
#   'right',
#   'now.',
#   '#depression',
#   '#economiccrisis',
#   '#americafirst'],
#  ['this', 'is', '#happiness,', '#welldone.'],
#  ['it',
#   'seems',
#   'like',
#   'the',
#   'disasters',
#   'never',
#   'end.',
#   'but',
#   'my',
#   'strength',
#   'has',
#   'grown',
#   'significantly.',
#   "i'm",
#   'on',
#   'the',
#   'right',
#   'meds,',
#   "i'm",
#   'using',
#   'the',
#   'right',
#   'tools,',
#   "i'm",
#   'in',
#   'therapy.',
#   '#depression',
#   '#anxiety',
#   '#mentalillness',
#   '#mentalhealthawareness'],
#  ['these',
#   'voices',
#   'in',
#   'my',
#   'head,',
#   'these',
#   'demons.',
#   'i',
#   'wish',
#   'they',
#   'would',
#   'go',
#   'away.',
#   'i',
#   'wanna',
#   'be',
#   'myself',
#   'again.',
#   '#depression'],
#  ['aww,',
#   'this',
#   'is',
#   'the',
#   'kind',
#   'of',
#   'friendship',
#   'we',
#   'all',
#   'need',
#   'in',
#   'our',
#   'lives!',
#   'so',
#   'heartwarming',
#   'to',
#   'see',
#   'a',
#   'simple',
#   'act',
#   'of',
#   'kindness',
#   'blossom',
#   'into',
#   'an',
#   '8-year-long',
#   'bond.',
#   '#friendshipgoals',
#   '#blessed',
#   'check',
#   'my',
#   'bio',
#   'plz'],
#  ['an☀️ther',
#   'day',
#   'another',
#   'gift.',
#   'thank',
#   'you',
#   'god🙏🏻',
#   '#gratitudeistheattitude',
#   '#thankful',
#   '#blessedandgrateful'],
#  ['#halitosis',
#   'is',
#   'also',
#   'associated',
#   'with',
#   '#depression',
#   'and',
#   'symptoms',
#   'of',
#   'obsessive',
#   'compulsive',
#   'disorder.'],
#  ['seek',
#   'happiness',
#   'and',
#   'find',
#   'joy',
#   'in',
#   'everyday',
#   'life',
#   '#upgradeyourlife',
#   '#happiness',
#   '#idavidclub'],
#  ['to',
#   'venture',
#   'out',
#   'would',
#   'be',
#   '#chaos',
#   'erupt',
#   '&amp;',
#   'pure',
#   '#anxiety',
#   '#ink2pad',
#   '#freemi',
#   '#8512',
#   '#factualinfebuary',
#   '#greatconversationalpiece',
#   '#jokerinfall',
#   '#1409april'],
#  ['congrats!',
#   'great',
#   'job',
#   'and',
#   'as',
#   'always',
#   'so',
#   'so',
#   'grateful',
#   'you',
#   'included',
#   'me.'],
#  ['thank',
#   'you',
#   ':]',
#   "i'll",
#   'keep',
#   'that',
#   'in',
#   'mind.',
#   'anxiety',
#   'sucks',
#   'man'],
#  ['i',
#   'keep',
#   'remembering',
#   'the',
#   'old',
#   'tumblr',
#   'meme:',
#   '"you',
#   'ruined',
#   'a',
#   'perfectly',
#   'good',
#   'website!',
#   'look',
#   'at',
#   'it!',
#   'it',
#   'has',
#   'anxiety!"'],
#  ['i',
#   'feel',
#   'like',
#   'something',
#   'is',
#   'brewing',
#   'between',
#   'china,',
#   'russia,',
#   'saudi',
#   'arabia,',
#   'and',
#   'iran.',
#   'i',
#   'have',
#   'that',
#   'feeling',
#   'that',
#   'the',
#   'attack',
#   'is',
#   'imminent,',
#   'like',
#   'pearl',
#   'harbor-type',
#   'shit.',
#   'it',
#   'could',
#   'be',
#   'just',
#   'my',
#   'anxiety.',
#   '#prayforamerica',
#   '#anxiety'],
#  ['so',
#   'many',
#   'good',
#   'people',
#   'around',
#   'me',
#   'supporting',
#   'what',
#   'i',
#   'do',
#   'with',
#   'these',
#   'kids',
#   '&amp;',
#   'giving',
#   'me',
#   'game',
#   'to',
#   'continue',
#   'growing',
#   'as',
#   'a',
#   'coach.',
#   'blessed',
#   '&amp;',
#   'thankful',
#   'to',
#   'those',
#   'helping',
#   'my',
#   'journey',
#   'so',
#   'i',
#   'can',
#   'keep',
#   'helping',
#   'these',
#   'kids',
#   'journeys.',
#   'i',
#   'just',
#   'wanna',
#   'see',
#   'all',
#   'these',
#   'kids',
#   'win',
#   'in',
#   'life!!',
#   '#thankful'],
#  ['we',
#   'all',
#   'have',
#   'lost',
#   'a',
#   'beautiful',
#   'bond',
#   'with',
#   'someone',
#   'special',
#   'which',
#   'we',
#   'wanted',
#   'forever.❤️',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#sadquotes',
#   '#quotes',
#   '#sad',
#   '#love',
#   '#lovequotes',
#   '#broken',
#   '#brokenheart',
#   '#depressed',
#   '#lifequotes',
#   '#feelings',
#   '#like',
#   '#sadness',
#   '#sadedits',
#   '#depression',
#   '#poetry',
#   '#heartbroken',
#   '#sadquotespage',
#   '#alone'],
#  ['we',
#   'all',
#   'know',
#   'pets',
#   'are',
#   'cute,',
#   'but',
#   'did',
#   'you',
#   'know',
#   'they',
#   'also',
#   'have',
#   'many',
#   'health',
#   'benefits',
#   'for',
#   'older',
#   'adults?',
#   'pets',
#   'are',
#   'a',
#   'great',
#   'way',
#   'to',
#   'decrease',
#   'loneliness',
#   'and',
#   'depression!',
#   'but',
#   'is',
#   'there',
#   'a',
#   'difference',
#   'for',
#   'dogs',
#   'vs.',
#   'cats…',
#   'where',
#   'do',
#   'you',
#   'fall?',
#   'link',
#   'in',
#   'thread!',
#   '#olderadults',
#   '#dogs',
#   '#cats',
#   '#loneliness'],
#  ['“burnout',
#   'happens',
#   'when',
#   'you',
#   'avoid',
#   'being',
#   'human',
#   'for',
#   'too',
#   'long”',
#   '#airmovie📷📷📷📷',
#   '#stressmanagement',
#   '#mentalhealthawareness',
#   '#doge',
#   '#anxiety',
#   '#onstorm',
#   '#wweraw📷📷📷',
#   '#nationalcaregiverday',
#   '#covidawarenessweek',
#   '#illness',
#   '#depression',
#   '#barbiemovie📷📷',
#   '#passover',
#   '#rhonj',
#   '#preds',
#   '#giveaway',
#   '#travel'],
#  ['when',
#   'you',
#   'feel',
#   'anxious',
#   'about',
#   'the',
#   'status',
#   'of',
#   'the',
#   'planet,',
#   'you',
#   'should',
#   'know',
#   'that',
#   "that's",
#   'the',
#   'feeling/status',
#   'of',
#   'your',
#   'environment,',
#   'trees',
#   'suffer',
#   'during',
#   'unfamiliar',
#   'changes',
#   'in',
#   'their',
#   'environments,',
#   'and',
#   'so',
#   'we',
#   'do!',
#   '#anxiety',
#   '#environment'],
#  ['anxiety',
#   'can',
#   'be',
#   'debilitating,',
#   'but',
#   'hypnotherapy',
#   'can',
#   'be',
#   'a',
#   'game-changer!',
#   'by',
#   'accessing',
#   'the',
#   'subconscious',
#   'mind,',
#   'hypnotherapy',
#   'can',
#   'help',
#   'reframe',
#   'negative',
#   'thought',
#   'patterns',
#   'and',
#   'promote',
#   'relaxation.',
#   'if',
#   "you're",
#   'struggling',
#   'with',
#   'anxiety,',
#   'consider',
#   'giving',
#   'hypnotherapy',
#   'a',
#   'try.',
#   '#hypnotherapy'],
#  ['should',
#   'we',
#   'start',
#   'bullying',
#   'people',
#   'with',
#   'depression?',
#   'how',
#   'about',
#   'anxiety?',
#   'is',
#   'it',
#   'cool',
#   'to',
#   'harass',
#   'people',
#   'with',
#   'ptsd?',
#   'you',
#   'clearly',
#   'lack',
#   'the',
#   'mental',
#   'ability',
#   'to',
#   'ever',
#   'be',
#   'a',
#   'doctor',
#   'so',
#   'how',
#   'about',
#   'you',
#   'stop',
#   'worrying',
#   'about',
#   'others',
#   'and',
#   'seek',
#   'some',
#   'treatment',
#   'for',
#   'your',
#   'issues?'],
#  ['in',
#   'contrast,',
#   'social',
#   'isolation',
#   'and',
#   'lack',
#   'of',
#   'social',
#   'support',
#   'have',
#   'been',
#   'linked',
#   'to',
#   'increased',
#   'risk',
#   'of',
#   'mental',
#   'health',
#   'issues',
#   'such',
#   'as',
#   'anxiety,',
#   'depression,',
#   'and',
#   'substance',
#   'abuse.'],
#  ['its',
#   'not',
#   'how',
#   'much',
#   'money',
#   'you',
#   'make',
#   'but',
#   'its',
#   'the',
#   'number',
#   'of',
#   'lives',
#   'that',
#   'are',
#   'positively',
#   'getting',
#   'effected',
#   'by',
#   'the',
#   'work',
#   'you',
#   'do.❤️',
#   '#startups',
#   '#entrepreneur',
#   '#entrepreneurmindset',
#   '#money',
#   '#lives',
#   '#business',
#   '#happiness',
#   '#genz',
#   '#impact'],
#  ['😍',
#   'my',
#   'dad',
#   'just',
#   'left',
#   'me',
#   'the',
#   'best',
#   'voicemail',
#   'ever.🥺',
#   'i',
#   'love',
#   'that',
#   'man',
#   'with',
#   'my',
#   'entire',
#   'heart.',
#   '#smalljoys',
#   '#thankful',
#   '#daddysprincess👑',
#   '#my',
#   'guy🙌🏾🙌🏾'],
#  ['where',
#   'are',
#   'all',
#   'the',
#   'grateful',
#   'ppl',
#   'that',
#   "don't",
#   'worry',
#   'about',
#   'money?',
#   "that's",
#   'where',
#   'i',
#   'need',
#   'to',
#   'be.'],
#  ['we’ve',
#   'always',
#   'been',
#   'there',
#   'for',
#   'people',
#   'in',
#   'their',
#   'time',
#   'of',
#   'need,',
#   'and',
#   'now',
#   'we’re',
#   'responding',
#   'to',
#   'the',
#   'deep',
#   'crisis',
#   'of',
#   '#loneliness',
#   'through',
#   'unconditional',
#   '#love',
#   'and',
#   '#community'],
#  ['thank',
#   'you',
#   'for',
#   'the',
#   'reminder.',
#   'for',
#   'me,',
#   'looking',
#   'forward',
#   'or',
#   'backward',
#   'leads',
#   'to:',
#   '-',
#   'regret',
#   '-',
#   'anxiety',
#   'both',
#   'of',
#   'which',
#   'dissolve',
#   'when',
#   'i',
#   'focus',
#   'on',
#   'the',
#   'now'],
#  ['is',
#   '#security',
#   'ultimately',
#   'about',
#   '#freedom',
#   'from',
#   '#pain,',
#   '#suffering,',
#   '&amp;',
#   '#death?',
#   'if',
#   'so,',
#   'this',
#   'seems',
#   'futile',
#   'as',
#   'all',
#   'of',
#   'the',
#   'above',
#   'are',
#   'guaranteed',
#   'in',
#   '#life.',
#   '#fear',
#   '#desire',
#   '#conflict',
#   '#control',
#   '#depression',
#   '#mentalhealth',
#   '#natureofthought',
#   '#werepeat',
#   '#weliveinconstantconflict',
#   '#awakeningofintelligence'],
#  ['to',
#   'suffer',
#   'some',
#   'anxiety,',
#   'some',
#   '#depression,',
#   'some',
#   '#disappointment,',
#   'even',
#   'some',
#   '#failure',
#   'is',
#   'normal.'],
#  ['personally',
#   'i',
#   'wait',
#   'until',
#   'the',
#   'streamer',
#   'is',
#   'no',
#   'longer',
#   'live',
#   'to',
#   'follow.',
#   'for',
#   'some',
#   'reason',
#   'my',
#   'anxiety',
#   'hates',
#   'getting',
#   'called',
#   'out',
#   'for',
#   'following,',
#   'especially',
#   'if',
#   "i've",
#   'known',
#   'them',
#   'for',
#   'a',
# ...
#   'minute,',
#   'day',
#   'by',
#   'day.',
#   'never',
#   'set',
#   'the',
#   '#expectation',
#   'for',
#   'lasting',
#   '#happiness',
#   'for',
#   'her',
#   '—',
#   'it',
#   'is',
#   'impossible.',
#   'why',
#   'set',
#   'yourself',
#   'up',
#   'for',
#   'failure?'],
#  ['space',
#   'available',
#   'in',
#   'my',
#   'brain.',
#   'you',
#   'can',
#   'live',
#   'there',
#   'completely',
#   'rent',
#   'free',
#   '#haiku',
#   '#poem',
#   '#mentalhealth',
#   '#anxiety',
#   '#intrusivethoughts'],
#  ['learning',
#   'from',
#   'many',
#   'including',
#   'you',
#   'dear',
#   'alan.',
#   'i',
#   'will',
#   'always',
#   'be',
#   'grateful',
#   'to',
#   'you.'],
#  ['living',
#   'a',
#   'good',
#   'life',
#   'is',
#   'all',
#   'about',
#   'finding',
#   'joy',
#   'in',
#   'the',
#   'little',
#   'things',
#   'and',
#   'making',
#   'the',
#   'most',
#   'of',
#   'every',
#   'moment!',
#   '#goodlife',
#   '#happiness'],
#  ['anyone',
#   'else',
#   'with',
#   '#anxiety',
#   'ever',
#   'contemplated',
#   'cancelling',
#   'an',
#   'appointment',
#   'because',
#   'they',
#   "didn't",
#   'know',
#   'where',
#   'it',
#   'was/what',
#   'the',
#   'parking',
#   'was',
#   'like?'],
#  ['this',
#   'is',
#   'how',
#   'to',
#   'show',
#   'a',
#   'loved',
#   'one',
#   'you',
#   'care:',
#   'have',
#   'you',
#   'talked',
#   'to',
#   'anyone',
#   'about',
#   'how',
#   'you',
#   'feel?',
#   '#mentalhealth',
#   '#depression'],
#  ['"stress',
#   'is',
#   'a',
#   'sign',
#   'you',
#   'have',
#   'lost',
#   'the',
#   'present',
#   'moment.',
#   'the',
#   'next',
#   'moment',
#   'has',
#   'become',
#   'more',
#   'important',
#   'than',
#   'life',
#   'itself."',
#   '—',
#   'eckhart',
#   'tolle',
#   '#stress',
#   '#anxiety',
#   '#overwhelm'],
#  ['they',
#   'bring',
#   'such',
#   'joy😁.',
#   'had',
#   'to',
#   'go',
#   'dogless',
#   'for',
#   'some',
#   'years',
#   'due',
#   'to',
#   'wrong',
#   'environmennt.',
#   'i’m',
#   'so',
#   'grateful',
#   'now',
#   'to',
#   'have',
#   'company',
#   'in',
#   'the',
#   'bathroom😂.'],
#  ['uhm.',
#   'so',
#   'yeah...',
#   "there's",
#   'a',
#   'big',
#   'black',
#   'snake',
#   'living',
#   'in',
#   'my',
#   'backyard...',
#   'and',
#   'i',
#   'am',
#   'now',
#   'irrationally',
#   'fearful',
#   'that',
#   'he',
#   'will',
#   'manage',
#   'to',
#   'somehow',
#   'find',
#   'his',
#   'way',
#   'in',
#   'my',
#   'house',
#   'and',
#   'bite',
#   'me',
#   'in',
#   'my',
#   'sleep....',
#   '🤦\u200d♀️',
#   '#anxiety'],
#  ['the',
#   'greatest',
#   'trick',
#   'the',
#   'devil',
#   'plays',
#   'on',
#   'us',
#   'is',
#   'to',
#   'keep',
#   'us',
#   'so',
#   'busy',
#   'we',
#   'don’t',
#   'recognize/appreciate',
#   'the',
#   'blessings',
#   'the',
#   'lord',
#   'has',
#   'given',
#   'us!',
#   'slow',
#   'down',
#   'and',
#   'be',
#   'thankful',
#   'the',
#   'lord',
#   'is',
#   'around',
#   'you,',
#   'take',
#   'peace',
#   'in',
#   'what',
#   'you',
#   'have!',
#   '#blessed',
#   '#thankful'],
#  ['being',
#   'in',
#   'a',
#   'bad',
#   'bout',
#   'of',
#   'depression',
#   'and',
#   'anxiety',
#   'during',
#   'passover',
#   'hits',
#   'different.',
#   'something',
#   'about',
#   'forty',
#   'years',
#   'in',
#   'the',
#   'desert.'],
#  ['#liveto100',
#   '#stressisakiller',
#   '#mentalhealth',
#   'day,',
#   'better',
#   'than',
#   'any',
#   'job.',
#   '#work',
#   'on',
#   '#happiness,',
#   '#liveto100.'],
#  ['i',
#   'think',
#   'i',
#   'have',
#   'butterflies',
#   'from',
#   'fantasizing',
#   'about',
#   'something',
#   'that',
#   'isn’t',
#   'real,',
#   'or',
#   'real',
#   'yet…',
#   'kinda',
#   'made',
#   'me',
#   'sad',
#   'but',
#   'the',
#   'butterflies',
#   'feel',
#   'happy',
#   'but',
#   'it’s',
#   'giving',
#   'me',
#   'anxiety'],
#  ['thanks!',
#   'experiences',
#   'of',
#   'actual',
#   'violence',
#   'in',
#   'my',
#   'life',
#   'make',
#   'it',
#   'not',
#   'funny',
#   'for',
#   'me.',
#   'some',
#   'amount',
#   'of',
#   'teasing',
#   "i'm",
#   'ok',
#   'w',
#   'but',
#   'the',
#   'b//m+',
#   'joke',
#   'i',
#   'honestly',
#   'find',
#   'anxiety',
#   'inducing',
#   'regardless',
#   'of',
#   'intent'],
#  ['even',
#   'a',
#   '#depression',
#   "won't",
#   'kill',
#   'a',
#   'beer',
#   'company',
#   'of',
#   'this',
#   'size.',
#   'meanwhile...',
#   '....',
#   '"hold',
#   'my',
#   'beer"',
#   '#gowokegobrokebudlight',
#   '#gowokegobrokebudweiser',
#   '#gowokegobroke'],
#  ['everyone',
#   'putting',
#   'the',
#   'chop',
#   'sticks',
#   'into',
#   'their',
#   'mouth',
#   'and',
#   'redipping',
#   'them',
#   'into',
#   'the',
#   'serving',
#   'bowls',
#   'is',
#   'giving',
#   'me',
#   'anxiety',
#   '😩😂'],
#  ['sometimes',
#   'you',
#   'have',
#   'to',
#   'kill',
#   'your',
#   'character',
#   'off',
#   'a',
#   'tv',
#   'show',
#   'you',
#   'no',
#   'longer',
#   'want',
#   'to',
#   'be',
#   'a',
#   'part',
#   'of!"',
#   '...now',
#   "i'm",
#   'starring',
#   'in',
#   'a',
#   'show',
#   'called',
#   'me!',
#   '#life',
#   '#happiness',
#   '#drama',
#   '#family',
#   '#friends'],
#  ['start',
#   'the',
#   'day',
#   'on',
#   'a',
#   'high',
#   'note',
#   'with',
#   'optimistic',
#   'thoughts',
#   'and',
#   'appreciation',
#   'in',
#   'your',
#   'heart.',
#   '🌈💖',
#   '#positivemindset',
#   '#thankful'],
#  ['i',
#   'am',
#   'free',
#   'from',
#   'jealousy.',
#   '#affirmation',
#   '#affirmations',
#   '#viral',
#   '#business',
#   '#affirmationnation',
#   '#wellbeing',
#   '#bekind',
#   '#dailyquotes',
#   '#fittip',
#   '#depression',
#   '#affirmationoftheday',
#   '#relationship',
#   '#lawofattraction',
#   '#healing',
#   '#encouragement',
#   '#goals',
#   '#words'],
#  ['at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'day,',
#   'i',
#   'realize',
#   'that',
#   'no',
#   'matter',
#   'how',
#   'good',
#   'i',
#   'am',
#   'to',
#   'people,',
#   'people',
#   'always',
#   'behave',
#   'according',
#   'to',
#   'their',
#   'mood',
#   'and',
#   'needs.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#sadquotes',
#   '#quotes',
#   '#sad',
#   '#love',
#   '#lovequotes',
#   '#broken',
#   '#brokenheart',
#   '#depressed',
#   '#lifequotes',
#   '#feelings',
#   '#like',
#   '#sadness',
#   '#sadedits',
#   '#depression',
#   '#poetr'],
#  ['i',
#   'never',
#   'thought',
#   "i'd",
#   'get',
#   'this',
#   'durable.',
#   'strong',
#   'enough',
#   'to',
#   'withstand',
#   'both',
#   'inner',
#   'and',
#   'outer',
#   'attacks',
#   'on',
#   'the',
#   'constant.',
#   'but',
#   'here',
#   'i',
#   'am.',
#   'ragged,',
#   'probably',
#   'crying',
#   'later.',
#   'but',
#   'here.',
#   'and',
#   'knowing',
#   'i',
#   'will',
#   'get',
#   'through',
#   'this.',
#   '#depression',
#   '#anxiety',
#   '#mentalillness',
#   '#mentalhealthawareness'],
#  ['our',
#   'kinder',
#   'program',
#   'emphasizes',
#   'holistic',
#   'and',
#   'comfortable',
#   'treatment',
#   'of',
#   'trauma',
#   'and',
#   'related',
#   'mental',
#   'health',
#   'disorders.',
#   'reach',
#   'out',
#   'for',
#   'help',
#   'to',
#   'get',
#   'started',
#   'today📲800-kik-4046',
#   '#womensmentalhealth',
#   '#holistichealing',
#   '#healing',
#   '#mentalhealth',
#   '#depression',
#   '#anxiety',
#   '#traumarecovery',
#   '#ptsd',
#   '#treatment'],
#  ['an',
#   'overthinking',
#   'girl',
#   'needs',
#   'an',
#   'understanding',
#   'guy.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '#sadquotes',
#   '#quotes',
#   '#sad',
#   '#love',
#   '#lovequotes',
#   '#broken',
#   '#brokenheart',
#   '#depressed',
#   '#lifequotes',
#   '#feelings',
#   '#like',
#   '#sadness',
#   '#sadedits',
#   '#depression',
#   '#poetry',
#   '#heartbroken',
#   '#sadquotespage',
#   '#alone'],
#  ['i',
#   'was',
#   'diagnosed',
#   'with',
#   'autism',
#   'almost',
#   '10',
#   'years',
#   'ago',
#   'at',
#   'age',
#   '37...',
#   'on',
#   'that',
#   'day,',
#   'i',
#   'finally',
#   'felt',
#   'like',
#   'i',
#   "wasn't",
#   'broken.',
#   '#autismawarenessmonth',
#   '#autismacceptance',
#   '#autism',
#   '#actuallyautistic',
#   '#autism',
#   '#depression'],
#  ['laugh',
#   'so',
#   'hard',
#   'i',
#   "couldn't",
#   'breathe.',
#   "haven't",
#   'laugh',
#   'like',
#   'this',
#   'for',
#   'a',
#   'long',
#   'time.',
#   '#thankful'],
#  ['having',
#   'a',
#   'very',
#   'difficult',
#   'time',
#   'getting',
#   '#anxiety',
#   'and',
#   '#insomnia',
#   'meds',
#   'in',
#   'nyc',
#   '&amp;',
#   "i'm",
#   'so',
#   'angry',
#   'about',
#   'being',
#   'treated',
#   'like',
#   'a',
#   'pill',
#   'popper',
#   'when',
#   'even',
#   'if',
#   'that',
#   'were',
#   'true',
#   "(it's",
#   'not)',
#   'this',
#   'is',
#   'much',
#   'worse',
#   'than',
#   'a',
#   'pill',
#   'habit.',
#   'i',
#   'hate',
#   'the',
#   'useless',
#   'dr.',
#   'i',
#   'saw.',
#   '"do',
#   'no',
#   'harm"',
#   '-',
#   'my',
#   'ass'],
#  ['business',
#   'is',
#   'stronger',
#   'than',
#   'ever.',
#   'with',
#   'growth',
#   'comes',
#   'change.',
#   'we',
#   'are',
#   'excited',
#   'to',
#   'announce',
#   'our',
#   'rebranding',
#   'that',
#   'better',
#   'reflects',
#   'the',
#   'added',
#   'resources',
#   '&amp;',
#   'broader',
#   'reach',
#   'to',
#   'serve',
#   'clients',
#   '&amp;',
#   'communities',
#   'more',
#   'effectively!',
#   'hi,',
#   "we're",
#   'apostle',
#   'radon',
#   'and',
#   'indoor',
#   'air',
#   'solutions!',
#   '#thankful',
#   '#excited'],
#  ['i', 'was', 'listening', 'to', 'the', 'anxiety', 'blender', 'last', 'week.'],
#  ['dear',
#   'parents,',
#   'thanks',
#   'for',
#   'shattering',
#   'your',
#   'baby',
#   'girl.',
#   'please',
#   'do',
#   'understand',
#   'that',
#   'she',
#   'would',
#   'need',
#   'a',
#   'couple',
#   'of',
#   'years',
#   'to',
#   'fix',
#   'herself',
#   'and',
#   'might',
#   'not',
#   'want',
#   'to',
#   'talk',
#   'to',
#   'you',
#   'again.',
#   'she',
#   'will',
#   'always',
#   'love',
#   'you,',
#   'in',
#   'life',
#   'and',
#   'death.',
#   'your',
#   'baby',
#   'girl',
#   '💙',
#   '#amwriting',
#   '#depressed',
#   '#brokenheart'],
#  ['i', 'am', 'thankful.', '#thankful'],
#  ['i', 'was', 'not', 'ready', 'to', 'be', 'alone', '#loneliness'],
#  ['doing',
#   'laundry',
#   'and',
#   'finding',
#   'money',
#   'in',
#   'my',
#   'pockets',
#   'i',
#   'forgot',
#   'about.',
#   'there',
#   'was',
#   'a',
#   'time',
#   'i',
#   'could',
#   'account',
#   'for',
#   'every',
#   'single',
#   'dollar',
#   'of',
#   'cash.',
#   'wasn’t',
#   'no',
#   '“forgotten”',
#   'money',
#   'in',
#   'pockets,',
#   'couches,',
#   'nada',
#   '#thankful'],
#  ['why',
#   'do',
#   'they',
#   'think',
#   'the',
#   '#2ndamendment',
#   'is',
#   'more',
#   'important',
#   'than',
#   'a',
#   "child's",
#   'right',
#   'to',
#   '#life,',
#   '#liberty',
#   '&amp;',
#   'the',
#   'pursuit',
#   'of',
#   '#happiness?',
#   'those',
#   'rights',
#   'are',
#   'in',
#   'the',
#   'second',
#   'paragraph',
#   'of',
#   'the',
#   'first',
#   'article',
#   'in',
#   'the',
#   'declaration',
#   'of',
#   'independence',
#   'which',
#   'comes',
#   'long',
#   'before',
#   'the',
#   'second',
#   'amendment.'],
#  ['no',
#   'updated',
#   'report',
#   'by',
#   'd',
#   'state',
#   'on',
#   'phd',
#   'students',
#   'in',
#   '#irish',
#   'unis',
#   'leave',
#   'alone',
#   'on',
#   '#migrant',
#   'phd',
#   'students',
#   'addressing',
#   'housing,',
#   'stipend,',
#   'harassment',
#   'etc.',
#   'writing',
#   'something',
#   'on',
#   '#loneliness',
#   'of',
#   'migrant',
#   'phd',
#   'students',
#   'in',
#   '#neoliberal',
#   'academia',
#   'n',
#   'dis',
#   'gross',
#   'lack',
#   'of',
#   'data',
#   'is',
#   'reinforcing',
#   'my',
#   'loneliness!'],
#  ['i',
#   'hope',
#   "i'm",
#   'not',
#   'too',
#   'late',
#   'for',
#   'a',
#   'blessing.',
#   'i',
#   'could',
#   'really',
#   'use',
#   'one',
#   'today.',
#   'not',
#   'just',
#   'financially',
#   'but',
#   'mentally',
#   'and',
#   'emotionally',
#   'as',
#   'well.',
#   '#depression',
#   'is',
#   'a',
#   'terrible',
#   'illness.'],
#  ['i’m',
#   'trying.',
#   'it’s',
#   'hard.',
#   'i’m',
#   'a',
#   'reactor.',
#   'i',
#   'want',
#   'to',
#   'do',
#   'better.',
#   '#cptsd',
#   '#anxiety'],
#  ['first',
#   'run',
#   'with',
#   'my',
#   'works',
#   'running',
#   'group',
#   'today.',
#   "i'm",
#   'terrified.',
#   'i',
#   'have',
#   'an',
#   'insane',
#   'fear',
#   'that',
#   "i'm",
#   'going',
#   'to',
#   'completely',
#   'forget',
#   'how',
#   'to',
#   'run,',
#   'like',
#   'some',
#   'kind',
#   'of',
#   'alien',
#   '😬',
#   '#anxiety',
#   '#running',
#   '#bristol10k'],
#  ['not',
#   'being',
#   'able',
#   'to',
#   'accept',
#   'the',
#   'love',
#   'you',
#   'receive',
#   'is',
#   'the',
#   'scariest',
#   'feeling',
#   'ever.',
#   '#trauma',
#   '#depression'],
#  ['anxiety', 'for', 'me'],
#  ['all',
#   'too',
#   'frequently,',
#   'anxiety',
#   'crushes',
#   'not',
#   'only',
#   'your',
#   'spirit',
#   'and',
#   'your',
#   'potential,',
#   'but',
#   'your',
#   'ability',
#   'to',
#   'take',
#   'care',
#   'of',
#   'your',
#   'mind',
#   'and',
#   'body.'],
#  ['separation',
#   'anxiety.',
#   'i',
#   'had',
#   'one',
#   'like',
#   'that',
#   'but',
#   'she',
#   'eventually',
#   'grew',
#   'out',
#   'of',
#   'being',
#   'destructive.',
#   'is',
#   'she',
#   'crate',
#   'trained?',
#   'that',
#   'can',
#   'help',
#   'a',
#   'lot',
#   'of',
#   'them',
#   'feel',
#   'secure,',
#   'especially',
#   'with',
#   'old',
#   'clothes',
#   'of',
#   'yours',
#   'to',
#   'comfort',
#   'her',
#   'when',
#   'you',
#   'aren’t',
#   'there.'],
#  ['so',
#   'it',
#   'turns',
#   'out',
#   'me',
#   'and',
#   'are',
#   'on',
#   'the',
#   'same',
#   'meds',
#   '💊',
#   '#sertraline',
#   'amazing',
#   'documentary',
#   'on',
#   'netflix!',
#   'got',
#   'so',
#   'much',
#   'admiration',
#   'for',
#   'him.',
#   'clearly',
#   'really',
#   'struggles',
#   'with',
#   'the',
#   'pressures',
#   'of',
#   'living',
#   'up',
#   'to',
#   'other',
#   "people's",
#   'expectations',
#   '#mentalhealth',
#   '#anxiety'],
#  ['these',
#   'real',
#   'estate',
#   'gurus',
#   'be',
#   'really',
#   'lying',
#   'on',
#   'the',
#   'internet',
#   'lol.',
#   'real',
#   'estate',
#   'requires',
#   'a',
#   'lot',
#   'of',
#   'patience',
#   '&amp;',
#   'it’s',
#   'not',
#   'a',
#   'get',
#   'rich',
#   'quick',
#   'scheme.',
#   'learned',
#   'so',
#   'much',
#   'this',
#   'year',
#   '🙏🏻',
#   '#thankful'],
#  ['you',
#   "don't",
#   'understand',
#   'depression',
#   'until',
#   'you',
#   "can't",
#   'stand',
#   'your',
#   'own',
#   'presence',
#   'in',
#   'an',
#   'empty',
#   'room.',
#   '#depression'],
#  ['drug',
#   'companies',
#   'are',
#   'already',
#   'interested',
#   'in',
#   'the',
#   'melanocortin',
#   'pathway',
#   'due',
#   'to',
#   'its',
#   'potential',
#   'involvement',
#   'in',
#   'appetite',
#   'disorders',
#   'and',
#   'anhedonia',
#   '(the',
#   'loss',
#   'of',
#   'the',
#   'ability',
#   'to',
#   'experience',
#   'pleasure).',
#   '#depression',
#   '#mentalhealth',
#   '#mentalhealthawareness',
#   '#health'],
#  ['if',
#   'you',
#   'have',
#   'anxiety',
#   'you',
#   'either',
#   'didn’t',
#   'do',
#   'you',
#   'bed',
#   'or',
#   'didn’t',
#   'get',
#   'up',
#   'early',
#   'to',
#   'cook',
#   '#virgo',
#   '#boat'],
#  ['definitely',
#   'give',
#   'it',
#   'a',
#   'go.',
#   'it',
#   'worked',
#   'really',
#   'well',
#   'for',
#   'depression',
#   'and',
#   'anxiety',
#   'for',
#   'me'],
#  ['money',
#   'is',
#   'great,',
#   'but',
#   'here',
#   'are',
#   'some',
#   'valuable',
#   'things',
#   'it',
#   "can't",
#   'buy:',
#   '-',
#   'reputation',
#   '-',
#   'love',
#   '-',
#   'trust',
#   '-',
#   'happiness',
#   'what',
#   'would',
#   'you',
#   'add?',
#   '#money',
#   '#love',
#   '#happiness'],
#  ['i',
#   'always',
#   'keep',
#   'a',
#   'box',
#   'of',
#   'tissues',
#   'by',
#   'my',
#   'bed',
#   'because',
#   'i',
#   'never',
#   'know',
#   'when',
#   'my',
#   'next',
#   'meltdown',
#   'will',
#   'be.',
#   '#anxiety',
#   '#depression'],
#  ['i’m',
#   'ready',
#   'to',
#   'be',
#   'great.',
#   'i’m',
#   'done',
#   'being',
#   'depressed.',
#   '#depression',
#   '#motivational'],
#  ["i'm",
#   'not',
#   'worried',
#   'about',
#   'ai',
#   'replacing',
#   'me',
#   'because',
#   'can',
#   'ai',
#   'get',
#   'a',
#   'panic',
#   'attack',
#   'after',
#   'receiving',
#   'a',
#   'simple',
#   'email?',
#   'no,',
#   'emails',
#   'will',
#   'always',
#   'find',
#   'ai',
#   'well.',
#   '#baddays',
#   '#anxiety'],
#  ['#sad',
#   '#story',
#   '#usa',
#   '#heart',
#   '#depression',
#   'it',
#   'was',
#   'a',
#   'dark',
#   'and',
#   'stormy',
#   'night,',
#   'the',
#   'rain',
#   'pouring',
#   'down',
#   'in',
#   'sheets',
#   'as',
#   'thunder',
#   'rumbled',
#   'in',
#   'the',
#   'distance.',
#   'sarah',
#   'sat',
#   'alone',
#   'in',
#   'her',
#   'apartment,',
#   'listening',
#   'to',
#   'the',
#   'storm',
#   'rage',
#   'outside.'],
#  ['what',
#   'year',
#   'would',
#   'you',
#   'go',
#   'back',
#   'to',
#   'if',
#   'you',
#   'had',
#   'a',
#   'time',
#   'machine?',
#   'if',
#   'you',
#   'have',
#   'no',
#   'desire',
#   'to',
#   'go',
#   'back',
#   'to',
#   'any',
#   'year,',
#   'it',
#   'might',
#   'imply',
#   'that',
#   'you',
#   'are',
#   'experiencing',
#   'a',
#   'type',
#   'of',
#   'depression',
#   '#depression'],
#  ['my',
#   'dad',
#   'saved',
#   'his',
#   "friend's",
#   'life',
#   'when',
#   'i',
#   'was',
#   'a',
#   'teenager.',
#   'his',
#   'friend',
#   'had',
#   'locked',
#   'himself',
#   'in',
#   'his',
#   'garage,',
#   'with',
#   'his',
#   'car',
#   'engine',
#   'running.',
#   '#suicide',
#   'and',
#   'attempts',
#   'at',
#   'happen',
#   'more',
#   'than',
#   'we',
#   'might',
#   'think.',
#   '#depression',
#   "isn't",
#   'feeling',
#   'sad.',
#   "it's",
#   'a',
#   'serious',
#   'condition.',
#   '#mentalhealth'],
#  ...]

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(text_data))

print(data_words[:1])
# Out:
# [['maybe', 'the', 'disasters', 'won', 'end', 'but', 'you', 'can', 'get', 'through', 'them', 'for', 'that', 'little', 'light', 'of', 'hope', 'that', 'still', 'there', 'in', 'you', 'know', 'it', 'is', 'promise', 'it', 'is', 'it', 'might', 'be', 'small', 'maybe', 'even', 'hidden', 'but', 'promise', 'you', 'it', 'there', 'depression', 'anxiety', 'mentalillness']]

# %%
data_words = list(sent_to_words(text_data))

# %%
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['maybe', 'the', 'disasters', 'won', 'end', 'but', 'you', 'can', 'get', 'through', 'them', 'for', 'that', 'little', 'light', 'of', 'hope', 'that', 'still', 'there', 'in', 'you', 'know', 'it', 'is', 'promise', 'it', 'is', 'it', 'might', 'be', 'small', 'maybe', 'even', 'hidden', 'but', 'promise', 'you', 'it', 'there', 'depression', 'anxiety', 'mentalillness']

# %%
stop_words = set(stopwords.words("english"))


def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# [['maybe', 'disaster', 'end', 'get', 'little', 'light', 'hope', 'still', 'know', 'promise', 'small', 'maybe', 'even', 'hidden', 'promise', 'depression', 'anxiety', 'mentalillness']]

# %%
dataset = []
for i in range(len(data_lemmatized)):
    dataset.append(" ".join(data_lemmatized[i]))
dataset = pd.Series(dataset)

# %%
no_features = 7000

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,3), max_features=no_features)
tfidf = tfidf_vectorizer.fit_transform(dataset)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(min_df=0.05,max_features=no_features)
tf = tf_vectorizer.fit_transform(dataset)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
no_topics = 2

# %%
from gensim.matutils import Sparse2Corpus
from gensim.models import HdpModel

# %%
no_topics = 2

# Run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5,max_iter=10000).fit(tfidf)

# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=10, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 25
print('NMF')
display_topics(nmf, tfidf_feature_names, no_top_words)
print('LDA')
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# NMF
# Topic 0:
# anxiety, depression, get, feel, go, give, give anxiety, anxiety depression, social, help, know, social anxiety, stress, take, depression anxiety, think, people, need, attack, bad, mentalhealth, really, work, anxiety attack, time
# Topic 1:
# happiness, grateful, thankful, life, love, happy, day, make, good, thank, thing, bless, time, gratitude, today, joy, get, people, feel, live, let, success, positivity, bring, go
# LDA
# Topic 0:
# anxiety, depression, get, feel, go, help, know, people, mentalhealth, think, take, time, make, good, day, today, love, thing, life, happy, grateful, thankful, happiness
# Topic 1:
# happiness, life, day, thankful, grateful, love, make, good, thing, happy, today, time, people, take, go, think, feel, know, get, help, anxiety, depression, mentalhealth

# %%
no_features = 7000

# Use TF-IDF for LSA
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 3), max_features=no_features)
tfidf = tfidf_vectorizer.fit_transform(dataset)

# Run LSA
lsa = TruncatedSVD(n_components=no_topics, algorithm='randomized', n_iter=100, random_state=1)
lsa.fit(tfidf)

# Print the top words for each topic
no_top_words = 25
print('LSA')
display_topics(lsa, tfidf_feature_names, no_top_words)
# Out:
# LSA
# Topic 0:
# anxiety, depression, happiness, get, feel, grateful, thankful, go, life, day, make, time, give, thing, love, people, know, good, take, help, today, think, happy, amp, work
# Topic 1:
# anxiety, give anxiety, social, social anxiety, anxiety depression, attack, anxiety attack, depression anxiety, give, stress, get anxiety, stress anxiety, separation anxiety, separation, anxiety get, affirmation anxiety, induce, anxiety anxiety, anxiety feel, help anxiety, go anxiety, hate, anxiety induce, disorder, anxiety really

# %%
corpus = Sparse2Corpus(tf.T)
hdp_model = HdpModel(corpus=corpus, id2word=dict((i, s) for i, s in enumerate(tf_feature_names)))

# print the top 10 topics and their top 10 words
topics = hdp_model.show_topics(num_topics=2, num_words=10, formatted=False)
#This should convert the matrix to a valid gensim corpus object and enable you to fit the HDP model to the data.

# %%
df = pd.read_csv('tweets4f.csv')

# Function to clean the text of each tweet
def clean_tweet_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove mentions
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    # Remove non-alphabetic characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Clean the text of each tweet in the dataframe
df['text'] = df['text'].apply(clean_tweet_text)

# Save the cleaned dataframe to a new CSV file
df.to_csv('tweets5f.csv', index=False)
#This code will remove URLs, mentions, hashtags, non-alphabetic characters, and extra spaces from the text of each tweet in the text column of the tweets4f.csv file. The cleaned dataframe will then be saved to a new CSV file named cleaned_tweets4f.csv which can be used for further analysis.

# %%
lda_output = lda.transform(tf)
# column names
topicnames = ['Topic' + str(i) for i in range(lda.n_components)]
# index names
docnames = ['Doc' + str(i) for i in range(len(dataset))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

df_document_topics = df_document_topic
dataset2 = pd.read_csv("tweets5f.csv")
df_document_topics.reset_index(inplace=True,drop=True)
dataset2['label'] = df_document_topics['dominant_topic']

# %%
nmf_output = nmf.transform(tfidf)
# column names
topicnames = ['Topic' + str(i) for i in range(nmf.n_components)]
# index names
docnames = ['Doc' + str(i) for i in range(len(dataset))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(nmf_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

df_document_topics = df_document_topic
dataset1 = pd.read_csv('tweets5f.csv')
df_document_topics.reset_index(inplace=True,drop=True)
dataset1['label'] = df_document_topics['dominant_topic']

# %%
for i in range(20):
    print(dataset1[dataset1['label']==0].iloc[i][1])
    print('\n')
# Out:
# maybe the disasters wont end but you can get through them for that little light of hope thats still there in you i know it is i promise it is it might be small maybe even hidden but i promise you its there
#
#
# i wish i didnt have social anxiety bc the things i would do to become an actor
#
#
# we understand this feeling
#
#
# i like having an empty mind no or i like and
#
#
# hunger is like being hungry in the least hungry way possible you know wanting food without having to eat it does that make sense anyways my cat is extremely sick right now so if im not avoiding twitter im crying see you soon with an unwanted update
#
#
# dear brothers is real but together we can prevent it with
#
#
# back in america
#
#
# both vague and anxiety inducing that said thank you for sharing what you can
#
#
# fankoo for sharing this today i feel utterly alone often amp this reminded me im not
#
#
# have you thought about getting help
#
#
# i want to die im going to hurt someone
#
#
# mama is triggering my anxiety
#
#
# is something that is an outside thing stress is an
#
#
# people who used to participate in every competition and cultural activity in school are struggling with social anxiety now
#
#
# for anyone struggling with and working on a project thats stressing you youre ok step back take a breath reassess if you need to read the manual its ok if you need to redo some work to correct something its ok you got this
#
#
# i could really use to get my daughters anxiety medication oniyamae
#
#
# music helps anxiety fr
#
#
# i dont need the i told you sos i just need to get through this
#
#
# t provides unique opportunities to enter childs beautiful world which helps parents to forget their however play should be on the terms and wishes of the child learning is best when it is child initiated free play
#
#
# it feels good to be still

# %%
tweets = np.array(text_data)
labels = np.array(dataset1['label'])
print(len(tweets),len(labels))
# Out:
# 7627 7627

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras import regularizers
max_words = 10000
max_len = 100

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(tweets)
sequences = tokenizer.texts_to_sequences(tweets)
tweets = pad_sequences(sequences, maxlen=max_len)
print(tweets)
# Out:
# [[   0    0    0 ...   15  306  111]
#  [   0    0    0 ...  455   62 6605]
#  [   0    0    0 ...    4 2607 5637]
#  ...
#  [   0    0    0 ...  108   29   12]
#  [   0    0    0 ...  154   20  196]
#  [   0    0    0 ... 5580 1153   12]]

# %%
for i in range(20):
    dataset1[dataset1['label']==0].iloc[i][1] = dataset1[dataset1['label']==0].iloc[i][1].lower()

# %%
X_train, X_test, y_train, y_test = train_test_split(tweets,labels, test_size=0.2, random_state=42)
print(X_train, X_train.shape, y_train.shape)
print(X_test, X_test.shape, y_test.shape)
print (len(X_train),len(X_test),len(y_train),len(y_test))
# Out:
# [[   0    0    0 ... 2469 2545 1367]
#  [   0    0    0 ...  250   96   55]
#  [   0    0    0 ...  427   15  540]
#  ...
#  [   0    0    0 ...   16    9   21]
#  [   0    0    0 ...   26   23  130]
#  [   0    0    0 ...  117   11   15]] (6101, 100) (6101,)
# [[   0    0    0 ...   16   70 3124]
#  [   0    0    0 ... 1969   12 1748]
#  [   0    0    0 ... 3262 1397   32]
#  ...
#  [   0    0    0 ... 2420  111 8623]
#  [   0    0    0 ... 1814  111   12]
#  [   0    0    0 ... 3995    2  996]] (1526, 100) (1526,)
# 6101 1526 6101 1526

# %%
print('Shape of X_train:', X_train.shape)
print('Shape of X_test:', X_test.shape)
# Out:
# Shape of X_train: (6101, 100)
# Shape of X_test: (1526, 100)

# %%
model1 = Sequential()
model1.add(layers.Embedding(max_words, 40))
model1.add(layers.LSTM(40,dropout=0.5))
model1.add(layers.Dense(1,activation='sigmoid'))

model1.compile(optimizer='rmsprop',loss='binary_crossentropy', metrics=['accuracy'])

history = model1.fit(X_train, y_train, epochs=7,validation_data=(X_test, y_test))
# Out:
# Epoch 1/7
# 2023-04-16 21:17:33.310453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:17:33.312889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:17:33.313985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:17:33.710503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:17:33.712397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:17:33.714619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:17:34.267532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:17:34.268607: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:17:34.270895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 189/191 [============================>.] - ETA: 0s - loss: 0.4344 - accuracy: 0.8056
# 2023-04-16 21:17:39.441352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:17:39.443153: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:17:39.445381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 191/191 [==============================] - 6s 24ms/step - loss: 0.4321 - accuracy: 0.8069 - val_loss: 0.2057 - val_accuracy: 0.9299
# Epoch 2/7
# 191/191 [==============================] - 4s 22ms/step - loss: 0.1453 - accuracy: 0.9490 - val_loss: 0.1254 - val_accuracy: 0.9509
# Epoch 3/7
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0943 - accuracy: 0.9692 - val_loss: 0.1133 - val_accuracy: 0.9607
# Epoch 4/7
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0664 - accuracy: 0.9775 - val_loss: 0.0892 - val_accuracy: 0.9640
# Epoch 5/7
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0545 - accuracy: 0.9813 - val_loss: 0.0789 - val_accuracy: 0.9725
# Epoch 6/7
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0437 - accuracy: 0.9859 - val_loss: 0.0785 - val_accuracy: 0.9744
# Epoch 7/7
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0364 - accuracy: 0.9890 - val_loss: 0.0759 - val_accuracy: 0.9764

# %%
model3 = Sequential()
model3.add(layers.Embedding(max_words, 40))
model3.add(layers.Bidirectional(layers.LSTM(40,dropout=0.5)))
model3.add(layers.Dense(1,activation='sigmoid'))

model3.compile(optimizer='rmsprop',loss='binary_crossentropy', metrics=['accuracy'])

history = model3.fit(X_train, y_train, epochs=8,validation_data=(X_test, y_test))
# Out:
# 2023-04-16 21:18:05.132340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:05.133393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:05.135067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:18:05.261081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-04-16 21:18:05.301645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:05.303281: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:05.304964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/8
# 2023-04-16 21:18:05.563738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:05.565802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:05.567788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:18:05.928091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-04-16 21:18:05.978401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:05.980001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:05.981300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:18:06.427794: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-04-16 21:18:06.747491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:06.750527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:06.751992: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:18:06.889988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-04-16 21:18:06.933382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:06.935496: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:06.937517: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:18:07.359315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 190/191 [============================>.] - ETA: 0s - loss: 0.4781 - accuracy: 0.7740
# 2023-04-16 21:18:13.813448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:13.814518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:13.816256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-16 21:18:13.944895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-04-16 21:18:13.986332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-16 21:18:13.987499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-16 21:18:13.988707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 191/191 [==============================] - 9s 34ms/step - loss: 0.4769 - accuracy: 0.7748 - val_loss: 0.2370 - val_accuracy: 0.9227
# Epoch 2/8
# 191/191 [==============================] - 6s 30ms/step - loss: 0.1576 - accuracy: 0.9469 - val_loss: 0.1416 - val_accuracy: 0.9502
# Epoch 3/8
# 191/191 [==============================] - 6s 32ms/step - loss: 0.1080 - accuracy: 0.9633 - val_loss: 0.1073 - val_accuracy: 0.9626
# Epoch 4/8
# 191/191 [==============================] - 6s 30ms/step - loss: 0.0741 - accuracy: 0.9754 - val_loss: 0.0968 - val_accuracy: 0.9653
# Epoch 5/8
# 191/191 [==============================] - 6s 31ms/step - loss: 0.0510 - accuracy: 0.9838 - val_loss: 0.1107 - val_accuracy: 0.9659
# Epoch 6/8
# 191/191 [==============================] - 6s 31ms/step - loss: 0.0473 - accuracy: 0.9849 - val_loss: 0.1155 - val_accuracy: 0.9659
# Epoch 7/8
# 191/191 [==============================] - 6s 30ms/step - loss: 0.0352 - accuracy: 0.9889 - val_loss: 0.0733 - val_accuracy: 0.9777
# Epoch 8/8
# 191/191 [==============================] - 6s 30ms/step - loss: 0.0308 - accuracy: 0.9898 - val_loss: 0.0725 - val_accuracy: 0.9777

# %%
test = np.array(['Everything is just great. I am so thankful for today '])
test_sequence = tokenizer.texts_to_sequences(test)
test_sequence = pad_sequences(test_sequence, maxlen=max_len)
test_prediction = model3.predict(test_sequence)
if np.around(test_prediction, decimals=0)[0][0] == 0.0:
    print('The model predicted depressive/anxious language')
else:
    print("The model predicted other type of language")
# Out:
# 1/1 [==============================] - 0s 22ms/step
# The model predicted other type of language
